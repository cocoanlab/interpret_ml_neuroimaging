# %% [markdown]
# # Part 0. Description
#
# This script is a part of our work on the intepretation of machine learning models in neuroimaging. See more [details](https://github.com/cocoanlab/interpret_ml_neuroimaging)
#
# In this example, we will classify **Heat pain trial** and **Rejection trial** fMRI data using Convolutional Neural Network (CNN) and we will use Layer-wise Relevance Propagation (LRP) [(Bach et al., 2015)](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0130140) to explain the predictions of the model.
#
# The data consists of **59 subjects**. Each subject has **8 heat trials** and **8 rejection trials**.
#
# We will do Leave-One-Subject-Out cross-validation which means 59-fold cross-validation will be executed. In order to track which subject is held-out as a test set, we save the model number matched with the subject number. For example, if `sub_01` is the test set (first fold cross-validation), then model name is `model_01`
#
# Since we have 59 folds's results and models, it will be difficult to manage all of them. So we will use data matrix so that we can easily handle the results and models.
#
# When initialized, the data Frame contains: `'data_path'`(**where the data is saved**), `'type'`(**which type of stimulus is used on this data**), `'type_onehot'`(**One-Hot encoding of type**), `'subject'`(**subject number**)
#
# After the CNN model training, the following columns will be added:
#
# `'predicted_type_onehot'`(**predicted type by trained CNN model**), `'model_name'`(**which model is used for prediction**), `'model_weight_path'`(**where the model weight is saved**), `'model_acc'`(**accuracy of model for test data sets**), `'model_loss'`(**loss of model for test data sets**)

# %%
#The following is an example of the output data matrix of this script. Do not execute this cell before you train CNN models.
df.head(n=20)
# Out:
#     Unnamed: 0  index                                          data_path  \
# 0            0      0  ../data/derivatives/trial_images/sub_01/heat_t...
# 1            1      1  ../data/derivatives/trial_images/sub_01/heat_t...
# 2            2      2  ../data/derivatives/trial_images/sub_01/heat_t...
# 3            3      3  ../data/derivatives/trial_images/sub_01/heat_t...
# 4            4      4  ../data/derivatives/trial_images/sub_01/heat_t...
# 5            5      5  ../data/derivatives/trial_images/sub_01/heat_t...
# 6            6      6  ../data/derivatives/trial_images/sub_01/heat_t...
# 7            7      7  ../data/derivatives/trial_images/sub_01/heat_t...
# 8            8      8  ../data/derivatives/trial_images/sub_02/heat_t...
# 9            9      9  ../data/derivatives/trial_images/sub_02/heat_t...
# 10          10     10  ../data/derivatives/trial_images/sub_02/heat_t...
# 11          11     11  ../data/derivatives/trial_images/sub_02/heat_t...
# 12          12     12  ../data/derivatives/trial_images/sub_02/heat_t...
# 13          13     13  ../data/derivatives/trial_images/sub_02/heat_t...
# 14          14     14  ../data/derivatives/trial_images/sub_02/heat_t...
# 15          15     15  ../data/derivatives/trial_images/sub_02/heat_t...
# 16          16     16  ../data/derivatives/trial_images/sub_03/heat_t...
# 17          17     17  ../data/derivatives/trial_images/sub_03/heat_t...
# 18          18     18  ../data/derivatives/trial_images/sub_03/heat_t...
# 19          19     19  ../data/derivatives/trial_images/sub_03/heat_t...
#
#     type  type_onehot subject  predicted_type_onehot model_name  \
# 0   heat            1  sub_01                      1   model_01
# 1   heat            1  sub_01                      1   model_01
# 2   heat            1  sub_01                      1   model_01
# 3   heat            1  sub_01                      0   model_01
# 4   heat            1  sub_01                      1   model_01
# 5   heat            1  sub_01                      1   model_01
# 6   heat            1  sub_01                      0   model_01
# 7   heat            1  sub_01                      1   model_01
# 8   heat            1  sub_02                      1   model_02
# 9   heat            1  sub_02                      1   model_02
# 10  heat            1  sub_02                      1   model_02
# 11  heat            1  sub_02                      1   model_02
# 12  heat            1  sub_02                      1   model_02
# 13  heat            1  sub_02                      1   model_02
# 14  heat            1  sub_02                      1   model_02
# 15  heat            1  sub_02                      1   model_02
# 16  heat            1  sub_03                      1   model_03
# 17  heat            1  sub_03                      1   model_03
# 18  heat            1  sub_03                      1   model_03
# 19  heat            1  sub_03                      1   model_03
#
#                                  model_weight_path  model_acc  model_loss
# 0   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 1   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 2   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 3   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 4   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 5   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 6   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 7   ../results/cnn_lrp/model_01/model_01_weight.h5     0.8750    0.117275
# 8   ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 9   ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 10  ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 11  ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 12  ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 13  ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 14  ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 15  ../results/cnn_lrp/model_02/model_02_weight.h5     0.8750    0.279192
# 16  ../results/cnn_lrp/model_03/model_03_weight.h5     0.9375    1.047622
# 17  ../results/cnn_lrp/model_03/model_03_weight.h5     0.9375    1.047622
# 18  ../results/cnn_lrp/model_03/model_03_weight.h5     0.9375    1.047622
# 19  ../results/cnn_lrp/model_03/model_03_weight.h5     0.9375    1.047622

# %% [markdown]
# # Part 1. Initializing Data Frame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nilearn import image
import nipype.interfaces.io as nio
import os

import tensorflow as tf
from sklearn.model_selection import LeaveOneGroupOut
from keras.models import load_model

# %matplotlib inline
# Out:
# /home/cocoan-gpu1/anaconda3/envs/tf3/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# 191126-00:35:32,244 nipype.utils INFO:
# 	 Running nipype version 1.2.3 (latest: 1.3.1)
# Using TensorFlow backend.

# %% [markdown]
# Setting base directory(`datapath`) for searching files and saving results(`result_path`, `dataframe_filename`)

# %%
datapath = '../data/derivatives/trial_images'
result_path = '../results/cnn_lrp'
dataframe_filename = 'cnn_lrp_dataframe.csv'

# %% [markdown]
# This is a template of files that you want to find in the base directory(`datapath`).

# %%
heat_search_template = 'sub_*/heat*.nii'
rejection_search_template = 'sub_*/rejection*.nii'

# %% [markdown]
# We will use `nipype.interfaces.io.DataGrabber()` to get the list of the files in the  directory.
#
# If you want to know the details of `DataGrabber()`, see this [reference](https://miykael.github.io/nipype_tutorial/notebooks/basic_data_input.html)

# %%
datasource = nio.DataGrabber()
datasource.inputs.base_directory = datapath
datasource.inputs.template = heat_search_template
datasource.inputs.sort_filelist = True
heat_imgs = datasource.run().outputs.get()['outfiles']

datasource.inputs.template = rejection_search_template
rejection_imgs = datasource.run().outputs.get()['outfiles']

all_imgs = np.concatenate((np.array(heat_imgs, dtype=object), np.array(rejection_imgs, dtype=object)))

# %% [markdown]
# Change data path from absolute path to relative path

# %%
def abs_path_to_rel(abs_path, break_point):
    split_path_list = []
    
    while True:
        abs_path, split_path = os.path.split(abs_path)
        split_path_list.append(split_path)

        if break_point in split_path:
            break

    for i in range(len(split_path_list)):
        if i == 0:
            rel_path = os.path.join('..', split_path_list[-(i+1)])
        else:
            rel_path = os.path.join(rel_path, split_path_list[-(i+1)])
            
    return rel_path

# %%
rel_all_imgs = []
for i in range(len(all_imgs)):
    rel_img_path = abs_path_to_rel(all_imgs[i], 'data')
    rel_all_imgs.append(rel_img_path)

# %% [markdown]
# Initializing data frame(`df`) with columns `data_path`, `type`, `type_onehot`, `subject`.

# %%
df = pd.DataFrame(rel_all_imgs, columns=['data_path'])
df['type']= None
df['type_onehot'] = None
df['subject']= None

# %% [markdown]
# This is basic usage of `Pandas`. If you are not familiar with `Pandas`, see
#
# [*Getting started*](https://pandas.pydata.org/pandas-docs/stable/getting_started/index.html)
#
# [`pandas.Series.str.find`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.find.html)
#
# [`pandas.Series.str.extract`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.extract.html)

# %%
df.loc[df[df['data_path'].str.find('heat')!=-1].index, 'type'] = 'heat'
df.loc[df[df['data_path'].str.find('reject')!=-1].index, 'type'] = 'reject'
df.loc[df[df['data_path'].str.find('heat')!=-1].index, 'type_onehot'] = 1
df.loc[df[df['data_path'].str.find('reject')!=-1].index, 'type_onehot'] = 0
df['subject'] = df['data_path'].str.extract(r'(sub_\d\d)')

df = df.replace(to_replace='None', value=np.nan).dropna()
df.reset_index(inplace=True)

# %% [markdown]
# You can see the first **n** rows of data frame using `df.head(n=n)`
#
# Since we have not trained the CNN model nor performed LRP, the data frame contains only details about our input data.  As we go further through the script, more columns will be added.

# %%
df.head(n=20)
# Out:
#     index                                          data_path  type  \
# 0       0  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 1       1  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 2       2  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 3       3  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 4       4  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 5       5  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 6       6  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 7       7  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 8       8  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 9       9  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 10     10  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 11     11  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 12     12  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 13     13  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 14     14  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 15     15  ../data/derivatives/trial_images/sub_02/heat_t...  heat
# 16     16  ../data/derivatives/trial_images/sub_03/heat_t...  heat
# 17     17  ../data/derivatives/trial_images/sub_03/heat_t...  heat
# 18     18  ../data/derivatives/trial_images/sub_03/heat_t...  heat
# 19     19  ../data/derivatives/trial_images/sub_03/heat_t...  heat
#
#     type_onehot subject
# 0             1  sub_01
# 1             1  sub_01
# 2             1  sub_01
# 3             1  sub_01
# 4             1  sub_01
# 5             1  sub_01
# 6             1  sub_01
# 7             1  sub_01
# 8             1  sub_02
# 9             1  sub_02
# 10            1  sub_02
# 11            1  sub_02
# 12            1  sub_02
# 13            1  sub_02
# 14            1  sub_02
# 15            1  sub_02
# 16            1  sub_03
# 17            1  sub_03
# 18            1  sub_03
# 19            1  sub_03

# %% [markdown]
# # Part 2. Loading Data Function
#
# The following code defines a function that we will use later to load data.

# %%
def load_dat(df, train_index, test_index, transpose_index=[3,2,1,0], do_masking=False, mask_path=None, do_masker = False):

    #Extract data path and labels from data matrix
    tr_path_X, te_path_X = df['data_path'][train_index].to_numpy(), df['data_path'][test_index].to_numpy()
    train_y, test_y = df['type_onehot'][train_index].to_numpy(), df['type_onehot'][test_index].to_numpy()
    
    from nilearn import image    
    
    if not do_masking:
        train_X = image.load_img(tr_path_X).get_fdata()
        test_X = image.load_img(te_path_X).get_fdata()
    
    elif do_masking:
        if do_masking and mask_path==None:
            raise ValueError('For masking, you need to set mask_path')
            
        from nilearn.masking import apply_mask, unmask
        from nilearn.image import resample_to_img
        from nilearn.input_data import NiftiMasker
            
        mask_img = image.load_img(mask_path)
        
        tr_X = image.load_img(tr_path_X)
        te_X = image.load_img(te_path_X)
        
        temp_img = image.load_img(tr_path_X[0])
        mask_img = resample_to_img(mask_img, temp_img, interpolation='nearest')
        
        #Extract bool mask from epi mask image
        if do_masker:
            masker = NiftiMasker(mask_strategy='epi')
            fitted_masker = masker.fit(mask_img)
            mask_img = fitted_masker.mask_img_
        
        tr_X = unmask(apply_mask(tr_X ,mask_img), mask_img)
        te_X = unmask(apply_mask(te_X ,mask_img), mask_img)
        
        train_X = tr_X.get_fdata()
        test_X = te_X.get_fdata()
    
    #Transpose matrix in order to match CNN model's input layer
    #Keras(or Tensorflow) is using (Number of data, height, width, channel) data shape for 2D image(https://keras.io/layers/convolutional/) and channel will be 'cutting axis'.
    #For brain images, nibabel using (x[left/Right;], y[posterior/Anterior], z[inferior/Superior], Number of data) data shape(https://nipy.org/nibabel/coordinate_systems.html).
    #You need to decide which axis will be cutting axis(like channel).
    #In this example, we choose 'x' axis as a cutting axis.
    #[x, y, z, N] => [N, z, y, x], ([79, 95, 68, N] => [N, 68, 95, 79])
    train_X = train_X.transpose(transpose_index)
    test_X = test_X.transpose(transpose_index)
    fmri_shape = train_X.shape[1:]
    
    return train_X, train_y, test_X, test_y, fmri_shape

# %% [markdown]
# # Part 3. CNN Model

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# We are using `Keras` for making CNN models
#
# You can see details of `Keras` usage in [here](https://keras.io/)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D
from keras.optimizers import Adam

# %% [markdown]
# make CNN model with **6 layers**, Flatten() is inserted between CNN and **fully connected layers**.

# %%
def make_custom_model_cnn_2D(fmri_shape):
    
    model = Sequential() 
    model.add(Conv2D(8, (3,3), kernel_initializer='he_normal', padding='same', input_shape=fmri_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))


    model.add(Conv2D(16, (3,3), kernel_initializer='he_normal', padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(32, (3,3), kernel_initializer='he_normal', padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3), kernel_initializer='he_normal', padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))


    model.add(Flatten()) 
    model.add(Dense(128, kernel_initializer='he_normal'))
    model.add(Activation('relu'))
    
    model.add(Dense(2, kernel_initializer='he_normal'))
    model.add(Activation('linear'))
    
    model.add(Activation('softmax'))
    
    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

    return model

# %% [markdown]
# Functions for creating & training model

# %%
def train_model(fmri_shape, train_X, train_y, test_X, test_y, mini_batch_size=128, epochs=200, patience=40):
    # Optional: if you do not have enough GPUs, use the following line  
    # with tf.device('/cpu:0'):
    
    tr_data = {}
    tr_data['X_data'] = train_X
    tr_data['y_data'] = train_y

    te_data = {}
    te_data['X_data'] = test_X
    te_data['y_data'] = test_y

    tr_data['y_data'] = keras.utils.to_categorical(tr_data['y_data'], 2)
    te_data['y_data'] = keras.utils.to_categorical(te_data['y_data'], 2)

    training_sample_count = tr_data['X_data'].shape[0]


    # Initialize and compile the model
    model = make_custom_model_cnn_2D(fmri_shape)
    model.compile(loss="categorical_crossentropy",
                  optimizer=Adam(),
                  metrics=["accuracy"])
    
    callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)]

    
    history = model.fit(tr_data['X_data'],
                        tr_data['y_data'],
                        batch_size=mini_batch_size,
                        epochs=epochs,
                        validation_data=(te_data['X_data'], te_data['y_data']),
                        callbacks=callbacks,
                        shuffle=True,
                        verbose=1)
    
    score = model.evaluate(te_data['X_data'], 
                           te_data['y_data'], 
                           verbose=0)
    
    print("\nTest Accuracy is {}\n".format(score[1]))
    
    return model,score

# %% [markdown]
# # Part 4. Model Training example

# %% [markdown]
# This is a 'test' training example for checking whether those codes are working.
#
# sub_01 will be the test dataset,
# the rest will be the training dataset

# %%
#LeaveOneGroupOut came from 'from sklearn.model_selection import LeaveOneGroupOut'
logo = LeaveOneGroupOut()

# %%
#sub_01 will be test set 
train_index, test_index = logo.split(X=df['data_path'], y=df['type_onehot'], groups=df['subject']=='sub_01')

train_index = train_index[1]
test_index = test_index[1]

#Load numpy array data from data path
train_X, train_y, test_X, test_y, fmri_shape = load_dat(df, train_index, test_index, transpose_index=[3,2,1,0])
print("train_X shape is {}".format(train_X.shape))
print("test_X shape is {}".format(test_X.shape))
# Out:
# train_X shape is (928, 68, 95, 79)
# test_X shape is (16, 68, 95, 79)

# %% [markdown]
# When you are using GPU(Graphics Processing Unit) for training, tensorflow automatically use all GPU memory even the model, we want to train, is not that much huge.
#
# In order to use GPU memory just as much we need, we can use `gpu_options.allow_growth = True` option from tensorflow

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
# Create & train model
model, score = train_model(fmri_shape, train_X, train_y, test_X, test_y, mini_batch_size=128, epochs=20, patience=20)
# Out:
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 2.3270 - acc: 0.5032 - val_loss: 1.0023 - val_acc: 0.4375
# Epoch 2/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.7843 - acc: 0.5226 - val_loss: 0.5969 - val_acc: 0.6875
# Epoch 3/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.6784 - acc: 0.6250 - val_loss: 0.5723 - val_acc: 0.9375
# Epoch 4/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.6041 - acc: 0.7414 - val_loss: 0.5000 - val_acc: 0.9375
# Epoch 5/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.5481 - acc: 0.7651 - val_loss: 0.3777 - val_acc: 0.9375
# Epoch 6/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.4583 - acc: 0.8567 - val_loss: 0.2468 - val_acc: 1.0000
# Epoch 7/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.3556 - acc: 0.8739 - val_loss: 0.1739 - val_acc: 0.9375
# Epoch 8/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.2707 - acc: 0.9009 - val_loss: 0.1114 - val_acc: 1.0000
# Epoch 9/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.2014 - acc: 0.9353 - val_loss: 0.0855 - val_acc: 1.0000
# Epoch 10/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.1512 - acc: 0.9526 - val_loss: 0.1489 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.1173 - acc: 0.9601 - val_loss: 0.0986 - val_acc: 0.9375
# Epoch 12/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0919 - acc: 0.9720 - val_loss: 0.0823 - val_acc: 1.0000
# Epoch 13/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0817 - acc: 0.9698 - val_loss: 0.0713 - val_acc: 1.0000
# Epoch 14/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0615 - acc: 0.9860 - val_loss: 0.1790 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0591 - acc: 0.9828 - val_loss: 0.1092 - val_acc: 0.9375
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0392 - acc: 0.9925 - val_loss: 0.0312 - val_acc: 1.0000
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0262 - acc: 0.9968 - val_loss: 0.0519 - val_acc: 1.0000
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0165 - acc: 0.9989 - val_loss: 0.1354 - val_acc: 0.8750
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0125 - acc: 1.0000 - val_loss: 0.0572 - val_acc: 0.9375
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 0.0678 - val_acc: 0.9375
#
# Test Accuracy is 0.9375

# %% [markdown]
# # Part 5. Leave-One-Subject-Out Cross-validation
#
# If the codes are working, we can perform 59-fold cross-validation.
#
# Keep in mind that **it will take hours**, depending on your computer performance.

# %%
logo = LeaveOneGroupOut()

#Making new colums to save results
df['predicted_type_onehot'] = None
df['model_name'] = None
df['model_weight_path'] = None
df['model_acc'] = None
df['model_loss'] = None

# %%
#Warning! It will take hours
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

#This time, it will be executed for all cross-validation sets
for i, (train_index, test_index) in enumerate(logo.split(X=df['data_path'], y=df['type_onehot'], groups=df['subject'])):
    
    #Load numpy array data from data path
    train_X, train_y, test_X, test_y, fmri_shape = load_dat(df, train_index, test_index, transpose_index=[3,2,1,0])
    print("Cross validation {}".format(i+1))
    
    #Create & train model
    model, score = train_model(fmri_shape, train_X, train_y, test_X, test_y, mini_batch_size=128, epochs=20, patience=20)  
    
    #Making model name for saving
    model_name = 'model_{:02d}'.format(i+1)
    model_path = os.path.join(result_path, model_name)
    model_path = abs_path_to_rel(model_path, 'results')
    
    #Create folders for saving model
    if not os.path.exists(model_path):
        os.makedirs(model_path)
        
    # We are going to save 'model without weight' and 'model's weight'
    # 'model without weight' is graph of cnn model without weight and will be saved as '.json' file. 
    # Since we used one cnn model for all cross-validation, we only need to save one model's graph.
    # 'model's weight' will be saved as '.h5' file and need to be saved for all trained model.
    
    #Saving Model's graph without trained weight
    if i == 0:
        model_file_path = os.path.join(result_path, ('model_without_weight.json'))
        model_json = model.to_json()
        with open(model_file_path, "w") as _file : 
            _file.write(model_json)
    
    #Saving Model's trained weight
    model_weight_file_path = os.path.join(model_path, (model_name + '_weight.h5'))
    model.save_weights(model_weight_file_path)
    
    print("{} is saved".format(model_name))
    
    #Saving results to the data frame
    df['model_name'][test_index] = model_name
    df['model_weight_path'][test_index] = model_weight_file_path
    df['model_acc'][test_index] = score[1]
    df['model_loss'][test_index] = score[0]
    
    #Getting predictions for test data using trained CNN model
    test_images = list(zip(test_X, test_y))
    for p, (x, y) in enumerate(test_images):
        # Add batch axis.
        x = x[None, :, :, :]

        #Prediction
        prob = model.predict_on_batch(x)[0]
        y_hat = prob.argmax()
        
        #Saving prediction results to the data frame
        df['predicted_type_onehot'][test_index[p]] = y_hat

    #Saving data frame as csv file format
    df_csv_path = os.path.join(result_path, dataframe_filename)
    df.to_csv(df_csv_path)
# Out:
# Cross validation 1
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 6s 7ms/step - loss: 2.4592 - acc: 0.5259 - val_loss: 1.0919 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.8409 - acc: 0.5226 - val_loss: 0.7160 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6760 - acc: 0.6067 - val_loss: 0.4856 - val_acc: 0.8125
# Epoch 4/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5827 - acc: 0.7511 - val_loss: 0.3654 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5049 - acc: 0.8028 - val_loss: 0.2470 - val_acc: 0.9375
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4169 - acc: 0.8373 - val_loss: 0.1622 - val_acc: 0.9375
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3386 - acc: 0.8642 - val_loss: 0.1392 - val_acc: 0.9375
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2898 - acc: 0.8825 - val_loss: 0.1158 - val_acc: 0.9375
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2368 - acc: 0.9106 - val_loss: 0.1350 - val_acc: 0.9375
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2139 - acc: 0.9159 - val_loss: 0.1389 - val_acc: 0.9375
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1608 - acc: 0.9494 - val_loss: 0.1074 - val_acc: 0.9375
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1234 - acc: 0.9655 - val_loss: 0.1259 - val_acc: 0.9375
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0983 - acc: 0.9720 - val_loss: 0.1609 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0889 - acc: 0.9741 - val_loss: 0.1961 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0911 - acc: 0.9688 - val_loss: 0.1755 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0682 - acc: 0.9817 - val_loss: 0.2397 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0454 - acc: 0.9946 - val_loss: 0.0720 - val_acc: 1.0000
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0325 - acc: 0.9925 - val_loss: 0.0787 - val_acc: 1.0000
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0203 - acc: 0.9989 - val_loss: 0.1351 - val_acc: 0.8750
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0131 - acc: 1.0000 - val_loss: 0.1173 - val_acc: 0.8750
#
# Test Accuracy is 0.875
#
# model_01 is saved
# Cross validation 2
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 2.5862 - acc: 0.5119 - val_loss: 0.6894 - val_acc: 0.4375
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.8751 - acc: 0.5431 - val_loss: 0.6877 - val_acc: 0.5625
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6826 - acc: 0.5323 - val_loss: 0.6615 - val_acc: 0.5000
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6094 - acc: 0.7306 - val_loss: 0.6022 - val_acc: 0.6875
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5323 - acc: 0.8050 - val_loss: 0.5383 - val_acc: 0.8125
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4413 - acc: 0.8308 - val_loss: 0.4570 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3681 - acc: 0.8610 - val_loss: 0.4239 - val_acc: 0.7500
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2904 - acc: 0.9041 - val_loss: 0.3361 - val_acc: 0.8125
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2349 - acc: 0.9235 - val_loss: 0.3242 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.1972 - acc: 0.9332 - val_loss: 0.2213 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1468 - acc: 0.9515 - val_loss: 0.2334 - val_acc: 0.8750
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1162 - acc: 0.9634 - val_loss: 0.2049 - val_acc: 0.8750
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0849 - acc: 0.9720 - val_loss: 0.1969 - val_acc: 0.9375
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0688 - acc: 0.9795 - val_loss: 0.2337 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0667 - acc: 0.9817 - val_loss: 0.2817 - val_acc: 0.8125
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0480 - acc: 0.9881 - val_loss: 0.2447 - val_acc: 0.9375
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0415 - acc: 0.9914 - val_loss: 0.3056 - val_acc: 0.7500
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0312 - acc: 0.9968 - val_loss: 0.3538 - val_acc: 0.8125
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0198 - acc: 0.9978 - val_loss: 0.2486 - val_acc: 0.8750
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0153 - acc: 1.0000 - val_loss: 0.2792 - val_acc: 0.8750
#
# Test Accuracy is 0.875
#
# model_02 is saved
# Cross validation 3
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 2.2134 - acc: 0.4774 - val_loss: 0.7234 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.7890 - acc: 0.5399 - val_loss: 0.9067 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6784 - acc: 0.5884 - val_loss: 0.7800 - val_acc: 0.5000
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6478 - acc: 0.6358 - val_loss: 0.7401 - val_acc: 0.5625
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6035 - acc: 0.7263 - val_loss: 0.7396 - val_acc: 0.5625
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5517 - acc: 0.7845 - val_loss: 0.7196 - val_acc: 0.7500
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4671 - acc: 0.8319 - val_loss: 0.6774 - val_acc: 0.8125
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3670 - acc: 0.8621 - val_loss: 0.5485 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2931 - acc: 0.8966 - val_loss: 0.4997 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2224 - acc: 0.9127 - val_loss: 0.5733 - val_acc: 0.8125
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1837 - acc: 0.9332 - val_loss: 0.4654 - val_acc: 0.9375
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1369 - acc: 0.9558 - val_loss: 0.6802 - val_acc: 0.9375
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1155 - acc: 0.9591 - val_loss: 0.7413 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0889 - acc: 0.9763 - val_loss: 0.7065 - val_acc: 0.9375
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0623 - acc: 0.9817 - val_loss: 0.7805 - val_acc: 0.9375
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0446 - acc: 0.9946 - val_loss: 0.7365 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0308 - acc: 0.9978 - val_loss: 0.7928 - val_acc: 0.8750
# Epoch 18/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0262 - acc: 0.9978 - val_loss: 1.0486 - val_acc: 0.9375
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0218 - acc: 0.9989 - val_loss: 1.0366 - val_acc: 0.9375
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0155 - acc: 1.0000 - val_loss: 1.0476 - val_acc: 0.9375
#
# Test Accuracy is 0.9375
#
# model_03 is saved
# Cross validation 4
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 1.4331 - acc: 0.5000 - val_loss: 0.6272 - val_acc: 0.8125
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6682 - acc: 0.5711 - val_loss: 0.5539 - val_acc: 0.8125
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5678 - acc: 0.7511 - val_loss: 0.4179 - val_acc: 1.0000
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4676 - acc: 0.8244 - val_loss: 0.2848 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3491 - acc: 0.8685 - val_loss: 0.1397 - val_acc: 1.0000
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2780 - acc: 0.9019 - val_loss: 0.0978 - val_acc: 1.0000
# Epoch 7/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2118 - acc: 0.9278 - val_loss: 0.0813 - val_acc: 1.0000
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1627 - acc: 0.9537 - val_loss: 0.0675 - val_acc: 1.0000
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1257 - acc: 0.9623 - val_loss: 0.0547 - val_acc: 1.0000
# Epoch 10/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0949 - acc: 0.9655 - val_loss: 0.0385 - val_acc: 1.0000
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0693 - acc: 0.9871 - val_loss: 0.0286 - val_acc: 1.0000
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0576 - acc: 0.9881 - val_loss: 0.0469 - val_acc: 1.0000
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1954 - acc: 0.9278 - val_loss: 0.0796 - val_acc: 0.9375
# Epoch 14/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0917 - acc: 0.9709 - val_loss: 0.0269 - val_acc: 1.0000
# Epoch 15/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0585 - acc: 0.9860 - val_loss: 0.0325 - val_acc: 1.0000
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0423 - acc: 0.9903 - val_loss: 0.0198 - val_acc: 1.0000
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0217 - acc: 1.0000 - val_loss: 0.0114 - val_acc: 1.0000
# Epoch 18/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0199 - acc: 0.9989 - val_loss: 0.0141 - val_acc: 1.0000
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0162 - acc: 0.9989 - val_loss: 0.0164 - val_acc: 1.0000
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0103 - acc: 1.0000 - val_loss: 0.0089 - val_acc: 1.0000
#
# Test Accuracy is 1.0
#
# model_04 is saved
# Cross validation 5
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 6s 6ms/step - loss: 1.3940 - acc: 0.5259 - val_loss: 0.7423 - val_acc: 0.6250
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.7002 - acc: 0.5647 - val_loss: 0.6495 - val_acc: 0.5625
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6035 - acc: 0.7155 - val_loss: 0.5712 - val_acc: 0.7500
# Epoch 4/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5078 - acc: 0.7996 - val_loss: 0.4627 - val_acc: 0.8125
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4059 - acc: 0.8448 - val_loss: 0.3732 - val_acc: 0.8750
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3240 - acc: 0.8685 - val_loss: 0.2767 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2709 - acc: 0.8901 - val_loss: 0.2708 - val_acc: 0.8125
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2173 - acc: 0.9203 - val_loss: 0.3722 - val_acc: 0.7500
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1755 - acc: 0.9343 - val_loss: 0.1669 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1365 - acc: 0.9461 - val_loss: 0.2894 - val_acc: 0.7500
# Epoch 11/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1049 - acc: 0.9580 - val_loss: 0.3976 - val_acc: 0.7500
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1082 - acc: 0.9580 - val_loss: 0.3218 - val_acc: 0.8125
# Epoch 13/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0998 - acc: 0.9688 - val_loss: 0.6601 - val_acc: 0.8125
# Epoch 14/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0816 - acc: 0.9752 - val_loss: 0.6996 - val_acc: 0.8125
# Epoch 15/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0800 - acc: 0.9677 - val_loss: 0.5630 - val_acc: 0.6875
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0682 - acc: 0.9774 - val_loss: 0.3828 - val_acc: 0.8125
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0515 - acc: 0.9828 - val_loss: 0.3948 - val_acc: 0.8125
# Epoch 18/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0362 - acc: 0.9914 - val_loss: 0.7437 - val_acc: 0.7500
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0265 - acc: 0.9957 - val_loss: 0.5327 - val_acc: 0.7500
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0151 - acc: 0.9989 - val_loss: 0.5972 - val_acc: 0.7500
#
# Test Accuracy is 0.75
#
# model_05 is saved
# Cross validation 6
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 6s 7ms/step - loss: 2.5363 - acc: 0.5075 - val_loss: 1.4254 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.7450 - acc: 0.6562 - val_loss: 1.0102 - val_acc: 0.6250
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5367 - acc: 0.7522 - val_loss: 0.5950 - val_acc: 0.7500
# Epoch 4/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4525 - acc: 0.8384 - val_loss: 0.6640 - val_acc: 0.6875
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3583 - acc: 0.8631 - val_loss: 0.9838 - val_acc: 0.6875
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2823 - acc: 0.8912 - val_loss: 1.4924 - val_acc: 0.6875
# Epoch 7/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2369 - acc: 0.9116 - val_loss: 1.3141 - val_acc: 0.6875
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1728 - acc: 0.9407 - val_loss: 0.8896 - val_acc: 0.6250
# Epoch 9/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1540 - acc: 0.9397 - val_loss: 1.6272 - val_acc: 0.6875
# Epoch 10/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1074 - acc: 0.9698 - val_loss: 1.9574 - val_acc: 0.6875
# Epoch 11/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0779 - acc: 0.9795 - val_loss: 1.4407 - val_acc: 0.6875
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0602 - acc: 0.9871 - val_loss: 1.4683 - val_acc: 0.6875
# Epoch 13/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0460 - acc: 0.9892 - val_loss: 2.0100 - val_acc: 0.6875
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0350 - acc: 0.9935 - val_loss: 2.1711 - val_acc: 0.6875
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0239 - acc: 0.9957 - val_loss: 1.8409 - val_acc: 0.6875
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0181 - acc: 0.9978 - val_loss: 1.7107 - val_acc: 0.6875
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0123 - acc: 1.0000 - val_loss: 1.8373 - val_acc: 0.6875
# Epoch 18/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0104 - acc: 1.0000 - val_loss: 2.0344 - val_acc: 0.6875
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0068 - acc: 1.0000 - val_loss: 2.1642 - val_acc: 0.6875
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 2.4665 - val_acc: 0.7500
#
# Test Accuracy is 0.75
#
# model_06 is saved
# Cross validation 7
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 6s 7ms/step - loss: 1.7739 - acc: 0.5172 - val_loss: 0.8827 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6935 - acc: 0.5862 - val_loss: 0.6556 - val_acc: 0.5625
# Epoch 3/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.6214 - acc: 0.7037 - val_loss: 0.6743 - val_acc: 0.5625
# Epoch 4/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.5275 - acc: 0.8006 - val_loss: 0.6322 - val_acc: 0.6250
# Epoch 5/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.4037 - acc: 0.8481 - val_loss: 0.6539 - val_acc: 0.6250
# Epoch 6/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.3133 - acc: 0.8675 - val_loss: 0.8254 - val_acc: 0.6875
# Epoch 7/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.2455 - acc: 0.9019 - val_loss: 0.8347 - val_acc: 0.6875
# Epoch 8/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.2029 - acc: 0.9224 - val_loss: 0.8807 - val_acc: 0.6250
# Epoch 9/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.1847 - acc: 0.9343 - val_loss: 0.7815 - val_acc: 0.6875
# Epoch 10/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.1645 - acc: 0.9386 - val_loss: 0.8339 - val_acc: 0.6875
# Epoch 11/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.1334 - acc: 0.9591 - val_loss: 0.9730 - val_acc: 0.6250
# Epoch 12/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.1022 - acc: 0.9666 - val_loss: 1.2034 - val_acc: 0.7500
# Epoch 13/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0827 - acc: 0.9752 - val_loss: 1.3071 - val_acc: 0.7500
# Epoch 14/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0640 - acc: 0.9774 - val_loss: 1.1300 - val_acc: 0.7500
# Epoch 15/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0436 - acc: 0.9935 - val_loss: 1.1797 - val_acc: 0.6250
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0350 - acc: 0.9957 - val_loss: 1.5950 - val_acc: 0.7500
# Epoch 17/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0244 - acc: 0.9968 - val_loss: 1.6782 - val_acc: 0.6875
# Epoch 18/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0208 - acc: 0.9989 - val_loss: 1.3504 - val_acc: 0.6250
# Epoch 19/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0148 - acc: 1.0000 - val_loss: 1.7737 - val_acc: 0.7500
# Epoch 20/20
# 928/928 [==============================] - 5s 5ms/step - loss: 0.0127 - acc: 1.0000 - val_loss: 1.7870 - val_acc: 0.7500
#
# Test Accuracy is 0.75
#
# model_07 is saved
# Cross validation 8
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 6s 6ms/step - loss: 1.5599 - acc: 0.4957 - val_loss: 0.9405 - val_acc: 0.4375
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.7011 - acc: 0.5733 - val_loss: 0.6794 - val_acc: 0.6875
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5358 - acc: 0.7759 - val_loss: 0.5452 - val_acc: 0.6250
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4167 - acc: 0.8287 - val_loss: 1.0619 - val_acc: 0.5625
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3542 - acc: 0.8642 - val_loss: 0.9028 - val_acc: 0.6250
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2871 - acc: 0.8879 - val_loss: 0.9509 - val_acc: 0.6250
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2273 - acc: 0.9073 - val_loss: 1.0501 - val_acc: 0.6250
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1886 - acc: 0.9203 - val_loss: 1.0539 - val_acc: 0.6250
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1491 - acc: 0.9397 - val_loss: 1.7767 - val_acc: 0.5000
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1200 - acc: 0.9515 - val_loss: 1.5962 - val_acc: 0.5625
# Epoch 11/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0937 - acc: 0.9720 - val_loss: 2.4798 - val_acc: 0.5000
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0694 - acc: 0.9849 - val_loss: 2.5440 - val_acc: 0.5000
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0485 - acc: 0.9903 - val_loss: 2.9846 - val_acc: 0.5000
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0471 - acc: 0.9892 - val_loss: 2.8646 - val_acc: 0.5625
# Epoch 15/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0318 - acc: 0.9968 - val_loss: 3.0694 - val_acc: 0.5625
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0223 - acc: 0.9978 - val_loss: 2.4779 - val_acc: 0.6250
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0210 - acc: 0.9989 - val_loss: 2.3117 - val_acc: 0.5625
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0173 - acc: 0.9978 - val_loss: 1.6035 - val_acc: 0.7500
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0207 - acc: 0.9968 - val_loss: 2.5880 - val_acc: 0.6250
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0151 - acc: 0.9978 - val_loss: 4.0140 - val_acc: 0.5625
#
# Test Accuracy is 0.5625
#
# model_08 is saved
# Cross validation 9
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 8ms/step - loss: 3.2541 - acc: 0.4666 - val_loss: 1.1251 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.9764 - acc: 0.5506 - val_loss: 1.1626 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.7471 - acc: 0.5291 - val_loss: 0.7194 - val_acc: 0.5000
# Epoch 4/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6430 - acc: 0.6379 - val_loss: 0.6750 - val_acc: 0.6875
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5541 - acc: 0.7920 - val_loss: 0.7235 - val_acc: 0.7500
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4321 - acc: 0.8427 - val_loss: 0.8644 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3557 - acc: 0.8545 - val_loss: 1.1288 - val_acc: 0.7500
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2882 - acc: 0.8869 - val_loss: 0.8593 - val_acc: 0.8125
# Epoch 9/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2463 - acc: 0.9041 - val_loss: 0.4538 - val_acc: 0.8125
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2202 - acc: 0.9159 - val_loss: 0.8439 - val_acc: 0.8125
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1770 - acc: 0.9397 - val_loss: 0.3144 - val_acc: 0.8750
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1651 - acc: 0.9332 - val_loss: 1.1679 - val_acc: 0.8125
# Epoch 13/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1219 - acc: 0.9547 - val_loss: 1.3303 - val_acc: 0.8125
# Epoch 14/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0958 - acc: 0.9698 - val_loss: 1.4114 - val_acc: 0.8125
# Epoch 15/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0820 - acc: 0.9752 - val_loss: 0.5596 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0687 - acc: 0.9817 - val_loss: 1.3901 - val_acc: 0.8125
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0491 - acc: 0.9914 - val_loss: 1.2866 - val_acc: 0.8125
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0374 - acc: 0.9935 - val_loss: 1.2813 - val_acc: 0.8125
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0297 - acc: 0.9968 - val_loss: 1.5069 - val_acc: 0.8125
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0190 - acc: 0.9989 - val_loss: 1.4241 - val_acc: 0.8125
#
# Test Accuracy is 0.8125
#
# model_09 is saved
# Cross validation 10
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 1.9073 - acc: 0.5162 - val_loss: 0.7739 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.7328 - acc: 0.5571 - val_loss: 0.7934 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6045 - acc: 0.6530 - val_loss: 0.6341 - val_acc: 0.6875
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5320 - acc: 0.7963 - val_loss: 0.6068 - val_acc: 0.7500
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4357 - acc: 0.8427 - val_loss: 0.4871 - val_acc: 0.7500
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3542 - acc: 0.8664 - val_loss: 0.4219 - val_acc: 0.9375
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2765 - acc: 0.9041 - val_loss: 0.3884 - val_acc: 0.9375
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2424 - acc: 0.8998 - val_loss: 0.3010 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1704 - acc: 0.9364 - val_loss: 0.2649 - val_acc: 0.9375
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1261 - acc: 0.9623 - val_loss: 0.2681 - val_acc: 0.9375
# Epoch 11/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0933 - acc: 0.9698 - val_loss: 0.2559 - val_acc: 0.9375
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0672 - acc: 0.9806 - val_loss: 0.1762 - val_acc: 0.9375
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0470 - acc: 0.9914 - val_loss: 0.1887 - val_acc: 0.9375
# Epoch 14/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0393 - acc: 0.9946 - val_loss: 0.1347 - val_acc: 0.9375
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0316 - acc: 0.9946 - val_loss: 0.1362 - val_acc: 0.9375
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0337 - acc: 0.9903 - val_loss: 0.2058 - val_acc: 0.9375
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0219 - acc: 0.9989 - val_loss: 0.1703 - val_acc: 0.9375
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0124 - acc: 1.0000 - val_loss: 0.1687 - val_acc: 0.9375
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0081 - acc: 1.0000 - val_loss: 0.2057 - val_acc: 0.9375
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 0.2531 - val_acc: 0.9375
#
# Test Accuracy is 0.9375
#
# model_10 is saved
# Cross validation 11
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 1.6405 - acc: 0.5302 - val_loss: 0.6663 - val_acc: 0.6250
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6868 - acc: 0.5668 - val_loss: 0.6092 - val_acc: 0.7500
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5564 - acc: 0.7996 - val_loss: 0.5841 - val_acc: 0.8125
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4561 - acc: 0.8071 - val_loss: 0.6356 - val_acc: 0.8125
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3551 - acc: 0.8588 - val_loss: 0.5592 - val_acc: 0.8750
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2798 - acc: 0.8879 - val_loss: 0.5301 - val_acc: 0.8750
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2266 - acc: 0.9213 - val_loss: 0.5883 - val_acc: 0.9375
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1797 - acc: 0.9300 - val_loss: 0.7697 - val_acc: 0.9375
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1913 - acc: 0.9149 - val_loss: 0.6866 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1405 - acc: 0.9494 - val_loss: 0.7645 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1083 - acc: 0.9601 - val_loss: 0.8080 - val_acc: 0.8750
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0792 - acc: 0.9774 - val_loss: 0.8032 - val_acc: 0.8750
# Epoch 13/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0648 - acc: 0.9774 - val_loss: 0.8543 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0448 - acc: 0.9903 - val_loss: 1.0379 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0348 - acc: 0.9957 - val_loss: 1.0531 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0267 - acc: 0.9957 - val_loss: 1.0854 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0188 - acc: 0.9978 - val_loss: 1.1163 - val_acc: 0.8750
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0121 - acc: 1.0000 - val_loss: 1.1712 - val_acc: 0.8750
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0086 - acc: 1.0000 - val_loss: 1.1848 - val_acc: 0.8750
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0066 - acc: 1.0000 - val_loss: 1.1220 - val_acc: 0.8750
#
# Test Accuracy is 0.875
#
# model_11 is saved
# Cross validation 12
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 8ms/step - loss: 1.2428 - acc: 0.5269 - val_loss: 0.7084 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5706 - acc: 0.7080 - val_loss: 0.7326 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4159 - acc: 0.8373 - val_loss: 0.4238 - val_acc: 0.8125
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3307 - acc: 0.8793 - val_loss: 0.3168 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2596 - acc: 0.9159 - val_loss: 0.2984 - val_acc: 0.8125
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2084 - acc: 0.9159 - val_loss: 0.4110 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1547 - acc: 0.9547 - val_loss: 0.2716 - val_acc: 0.8125
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1124 - acc: 0.9634 - val_loss: 0.1946 - val_acc: 0.9375
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0880 - acc: 0.9731 - val_loss: 0.3042 - val_acc: 0.9375
# Epoch 10/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0862 - acc: 0.9720 - val_loss: 0.2045 - val_acc: 0.9375
# Epoch 11/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0707 - acc: 0.9817 - val_loss: 0.2134 - val_acc: 0.8750
# Epoch 12/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0430 - acc: 0.9946 - val_loss: 0.1495 - val_acc: 0.8750
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0343 - acc: 0.9957 - val_loss: 0.1508 - val_acc: 0.9375
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0284 - acc: 0.9957 - val_loss: 0.3523 - val_acc: 0.9375
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0182 - acc: 0.9978 - val_loss: 0.4916 - val_acc: 0.9375
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0160 - acc: 0.9989 - val_loss: 0.2888 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0112 - acc: 1.0000 - val_loss: 0.3926 - val_acc: 0.9375
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0073 - acc: 1.0000 - val_loss: 0.3168 - val_acc: 0.9375
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0050 - acc: 1.0000 - val_loss: 0.2877 - val_acc: 0.9375
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.2660 - val_acc: 0.9375
#
# Test Accuracy is 0.9375
#
# model_12 is saved
# Cross validation 13
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 7ms/step - loss: 1.7248 - acc: 0.5011 - val_loss: 0.7846 - val_acc: 0.5625
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6992 - acc: 0.5819 - val_loss: 0.7032 - val_acc: 0.6250
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5991 - acc: 0.6864 - val_loss: 0.6169 - val_acc: 0.6250
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4991 - acc: 0.8233 - val_loss: 0.5035 - val_acc: 0.8125
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3622 - acc: 0.8631 - val_loss: 0.4219 - val_acc: 0.8750
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2872 - acc: 0.8912 - val_loss: 0.3935 - val_acc: 0.8750
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2776 - acc: 0.8825 - val_loss: 0.5280 - val_acc: 0.6250
# Epoch 8/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.2128 - acc: 0.9127 - val_loss: 0.6171 - val_acc: 0.7500
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1620 - acc: 0.9407 - val_loss: 0.4053 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1286 - acc: 0.9494 - val_loss: 0.3695 - val_acc: 0.8125
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0950 - acc: 0.9709 - val_loss: 0.4052 - val_acc: 0.8125
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0773 - acc: 0.9763 - val_loss: 0.3640 - val_acc: 0.8125
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0565 - acc: 0.9828 - val_loss: 0.4058 - val_acc: 0.8125
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0356 - acc: 0.9957 - val_loss: 0.4611 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0239 - acc: 0.9989 - val_loss: 0.5434 - val_acc: 0.7500
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0169 - acc: 1.0000 - val_loss: 0.5177 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0109 - acc: 1.0000 - val_loss: 0.4989 - val_acc: 0.8750
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 0.5491 - val_acc: 0.8125
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.5684 - val_acc: 0.8125
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0044 - acc: 1.0000 - val_loss: 0.6053 - val_acc: 0.8125
#
# Test Accuracy is 0.8125
#
# model_13 is saved
# Cross validation 14
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 8ms/step - loss: 1.4949 - acc: 0.5075 - val_loss: 0.7273 - val_acc: 0.6875
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6566 - acc: 0.6325 - val_loss: 0.6401 - val_acc: 0.7500
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5325 - acc: 0.7629 - val_loss: 0.6885 - val_acc: 0.6250
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4239 - acc: 0.8330 - val_loss: 0.6356 - val_acc: 0.8125
# Epoch 5/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.3684 - acc: 0.8599 - val_loss: 0.6795 - val_acc: 0.7500
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2999 - acc: 0.8728 - val_loss: 0.5405 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2764 - acc: 0.8955 - val_loss: 0.6022 - val_acc: 0.7500
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2339 - acc: 0.9203 - val_loss: 0.3810 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1830 - acc: 0.9407 - val_loss: 0.4594 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1344 - acc: 0.9569 - val_loss: 0.3911 - val_acc: 0.9375
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0956 - acc: 0.9731 - val_loss: 0.4399 - val_acc: 0.8125
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0772 - acc: 0.9709 - val_loss: 0.3897 - val_acc: 0.9375
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0557 - acc: 0.9925 - val_loss: 0.3026 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0412 - acc: 0.9935 - val_loss: 0.2992 - val_acc: 0.9375
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0253 - acc: 0.9968 - val_loss: 0.3334 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0173 - acc: 1.0000 - val_loss: 0.3249 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0132 - acc: 1.0000 - val_loss: 0.2451 - val_acc: 0.9375
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0093 - acc: 1.0000 - val_loss: 0.2913 - val_acc: 0.9375
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0070 - acc: 1.0000 - val_loss: 0.3119 - val_acc: 0.9375
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0059 - acc: 1.0000 - val_loss: 0.1983 - val_acc: 0.9375
#
# Test Accuracy is 0.9375
#
# model_14 is saved
# Cross validation 15
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 8ms/step - loss: 1.7696 - acc: 0.5593 - val_loss: 0.4478 - val_acc: 0.8125
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6293 - acc: 0.6907 - val_loss: 0.6969 - val_acc: 0.6875
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5271 - acc: 0.7759 - val_loss: 0.3838 - val_acc: 0.8750
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4280 - acc: 0.8244 - val_loss: 0.2456 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3220 - acc: 0.8825 - val_loss: 0.2011 - val_acc: 0.9375
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2724 - acc: 0.8955 - val_loss: 0.0929 - val_acc: 1.0000
# Epoch 7/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2023 - acc: 0.9310 - val_loss: 0.0516 - val_acc: 1.0000
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1719 - acc: 0.9397 - val_loss: 0.0342 - val_acc: 1.0000
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1773 - acc: 0.9310 - val_loss: 0.1033 - val_acc: 0.9375
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1192 - acc: 0.9569 - val_loss: 0.0515 - val_acc: 1.0000
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0943 - acc: 0.9709 - val_loss: 0.0493 - val_acc: 1.0000
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0728 - acc: 0.9806 - val_loss: 0.0202 - val_acc: 1.0000
# Epoch 13/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0532 - acc: 0.9881 - val_loss: 0.0153 - val_acc: 1.0000
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0354 - acc: 0.9978 - val_loss: 0.0195 - val_acc: 1.0000
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0265 - acc: 0.9989 - val_loss: 0.0169 - val_acc: 1.0000
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0253 - acc: 0.9957 - val_loss: 0.0078 - val_acc: 1.0000
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0154 - acc: 1.0000 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0109 - acc: 1.0000 - val_loss: 0.0054 - val_acc: 1.0000
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.0084 - val_acc: 1.0000
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0069 - acc: 1.0000 - val_loss: 0.0043 - val_acc: 1.0000
#
# Test Accuracy is 1.0
#
# model_15 is saved
# Cross validation 16
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 8ms/step - loss: 1.5722 - acc: 0.5409 - val_loss: 1.4093 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.7465 - acc: 0.5442 - val_loss: 0.5962 - val_acc: 0.6250
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6215 - acc: 0.6810 - val_loss: 0.6547 - val_acc: 0.6875
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5347 - acc: 0.8071 - val_loss: 0.3736 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4172 - acc: 0.8427 - val_loss: 0.1894 - val_acc: 1.0000
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3415 - acc: 0.8631 - val_loss: 0.1469 - val_acc: 0.9375
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2586 - acc: 0.8976 - val_loss: 0.1437 - val_acc: 0.9375
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1991 - acc: 0.9278 - val_loss: 0.1592 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1568 - acc: 0.9515 - val_loss: 0.2117 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1761 - acc: 0.9235 - val_loss: 0.1083 - val_acc: 0.9375
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1313 - acc: 0.9547 - val_loss: 0.0978 - val_acc: 1.0000
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1133 - acc: 0.9601 - val_loss: 0.0808 - val_acc: 1.0000
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0765 - acc: 0.9763 - val_loss: 0.0785 - val_acc: 0.9375
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0531 - acc: 0.9838 - val_loss: 0.0663 - val_acc: 0.9375
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0447 - acc: 0.9892 - val_loss: 0.0461 - val_acc: 1.0000
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0288 - acc: 0.9957 - val_loss: 0.0560 - val_acc: 0.9375
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0214 - acc: 0.9978 - val_loss: 0.0534 - val_acc: 1.0000
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0161 - acc: 0.9989 - val_loss: 0.0480 - val_acc: 1.0000
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0129 - acc: 0.9989 - val_loss: 0.0483 - val_acc: 1.0000
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0103 - acc: 1.0000 - val_loss: 0.0524 - val_acc: 0.9375
#
# Test Accuracy is 0.9375
#
# model_16 is saved
# Cross validation 17
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 7s 8ms/step - loss: 2.3153 - acc: 0.5183 - val_loss: 0.4342 - val_acc: 0.8750
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.8234 - acc: 0.5453 - val_loss: 0.3402 - val_acc: 0.9375
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6130 - acc: 0.6821 - val_loss: 0.3167 - val_acc: 1.0000
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5105 - acc: 0.7877 - val_loss: 0.2535 - val_acc: 0.9375
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4434 - acc: 0.8459 - val_loss: 0.2225 - val_acc: 0.9375
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4658 - acc: 0.7953 - val_loss: 0.1910 - val_acc: 1.0000
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4429 - acc: 0.8179 - val_loss: 0.0870 - val_acc: 1.0000
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3078 - acc: 0.8825 - val_loss: 0.0391 - val_acc: 1.0000
# Epoch 9/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2644 - acc: 0.9019 - val_loss: 0.0529 - val_acc: 1.0000
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2156 - acc: 0.9052 - val_loss: 0.0177 - val_acc: 1.0000
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1836 - acc: 0.9332 - val_loss: 0.0164 - val_acc: 1.0000
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1442 - acc: 0.9494 - val_loss: 0.0192 - val_acc: 1.0000
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1150 - acc: 0.9601 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0953 - acc: 0.9655 - val_loss: 0.0069 - val_acc: 1.0000
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0685 - acc: 0.9849 - val_loss: 0.0109 - val_acc: 1.0000
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0532 - acc: 0.9903 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0429 - acc: 0.9957 - val_loss: 0.0108 - val_acc: 1.0000
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0334 - acc: 0.9946 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0244 - acc: 0.9968 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0196 - acc: 1.0000 - val_loss: 0.0047 - val_acc: 1.0000
#
# Test Accuracy is 1.0
#
# model_17 is saved
# Cross validation 18
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 8s 8ms/step - loss: 2.2272 - acc: 0.4860 - val_loss: 0.5597 - val_acc: 0.6875
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.8016 - acc: 0.5409 - val_loss: 0.5401 - val_acc: 0.8125
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6047 - acc: 0.7177 - val_loss: 0.4439 - val_acc: 0.8125
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4883 - acc: 0.7953 - val_loss: 0.3081 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4013 - acc: 0.8502 - val_loss: 0.2653 - val_acc: 0.8750
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3268 - acc: 0.8718 - val_loss: 0.2138 - val_acc: 0.8750
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2679 - acc: 0.9052 - val_loss: 0.1897 - val_acc: 0.8750
# Epoch 8/20
# ...
# Epoch 5/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4736 - acc: 0.8114 - val_loss: 0.4594 - val_acc: 0.8125
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3897 - acc: 0.8491 - val_loss: 0.4947 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3085 - acc: 0.8836 - val_loss: 0.6101 - val_acc: 0.7500
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2498 - acc: 0.9019 - val_loss: 0.5167 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1987 - acc: 0.9246 - val_loss: 0.5070 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1556 - acc: 0.9472 - val_loss: 0.5557 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1274 - acc: 0.9558 - val_loss: 0.6268 - val_acc: 0.8750
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0958 - acc: 0.9698 - val_loss: 0.6166 - val_acc: 0.8750
# Epoch 13/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0728 - acc: 0.9795 - val_loss: 0.7187 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0537 - acc: 0.9881 - val_loss: 0.7947 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0456 - acc: 0.9903 - val_loss: 0.8774 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0328 - acc: 0.9914 - val_loss: 0.8008 - val_acc: 0.8125
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0323 - acc: 0.9925 - val_loss: 0.8946 - val_acc: 0.8125
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0233 - acc: 0.9968 - val_loss: 0.8644 - val_acc: 0.8125
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0169 - acc: 0.9989 - val_loss: 0.7959 - val_acc: 0.8750
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0296 - acc: 0.9957 - val_loss: 1.1874 - val_acc: 0.8125
#
# Test Accuracy is 0.8125
#
# model_54 is saved
# Cross validation 55
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 11s 11ms/step - loss: 1.6565 - acc: 0.5237 - val_loss: 0.8494 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.8594 - acc: 0.5808 - val_loss: 0.5775 - val_acc: 0.5625
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6323 - acc: 0.6789 - val_loss: 0.4960 - val_acc: 0.8750
# Epoch 4/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4990 - acc: 0.7888 - val_loss: 0.3616 - val_acc: 0.9375
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4036 - acc: 0.8427 - val_loss: 0.3292 - val_acc: 0.8125
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3160 - acc: 0.8728 - val_loss: 0.2947 - val_acc: 0.8750
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2481 - acc: 0.8976 - val_loss: 0.4058 - val_acc: 0.8125
# Epoch 8/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.2200 - acc: 0.9203 - val_loss: 0.4237 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2036 - acc: 0.9149 - val_loss: 0.3371 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1438 - acc: 0.9483 - val_loss: 0.3651 - val_acc: 0.7500
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1079 - acc: 0.9644 - val_loss: 0.4109 - val_acc: 0.7500
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0843 - acc: 0.9741 - val_loss: 0.4048 - val_acc: 0.8750
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0605 - acc: 0.9849 - val_loss: 0.3228 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0452 - acc: 0.9925 - val_loss: 0.4049 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0347 - acc: 0.9968 - val_loss: 0.4124 - val_acc: 0.7500
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0236 - acc: 0.9989 - val_loss: 0.4419 - val_acc: 0.8125
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0184 - acc: 1.0000 - val_loss: 0.4749 - val_acc: 0.8750
# Epoch 18/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0140 - acc: 1.0000 - val_loss: 0.5304 - val_acc: 0.7500
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0104 - acc: 1.0000 - val_loss: 0.5573 - val_acc: 0.7500
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0081 - acc: 1.0000 - val_loss: 0.5791 - val_acc: 0.7500
#
# Test Accuracy is 0.75
#
# model_55 is saved
# Cross validation 56
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 11s 11ms/step - loss: 2.6946 - acc: 0.4849 - val_loss: 1.0239 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.8213 - acc: 0.5108 - val_loss: 0.7203 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6791 - acc: 0.5991 - val_loss: 0.6767 - val_acc: 0.5625
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6409 - acc: 0.5981 - val_loss: 0.6433 - val_acc: 0.5625
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5661 - acc: 0.7683 - val_loss: 0.5612 - val_acc: 0.6250
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4855 - acc: 0.8190 - val_loss: 0.4722 - val_acc: 0.8125
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4257 - acc: 0.8287 - val_loss: 0.5101 - val_acc: 0.6250
# Epoch 8/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.3480 - acc: 0.8739 - val_loss: 0.4862 - val_acc: 0.6875
# Epoch 9/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.3043 - acc: 0.8879 - val_loss: 0.4769 - val_acc: 0.6875
# Epoch 10/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.2569 - acc: 0.9106 - val_loss: 0.4160 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2210 - acc: 0.9256 - val_loss: 0.5146 - val_acc: 0.6875
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1654 - acc: 0.9440 - val_loss: 0.6988 - val_acc: 0.6250
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1433 - acc: 0.9504 - val_loss: 0.4812 - val_acc: 0.6875
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1357 - acc: 0.9483 - val_loss: 0.6528 - val_acc: 0.6250
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1704 - acc: 0.9386 - val_loss: 0.3226 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1272 - acc: 0.9688 - val_loss: 0.3416 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1160 - acc: 0.9666 - val_loss: 0.4470 - val_acc: 0.7500
# Epoch 18/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0801 - acc: 0.9784 - val_loss: 0.6391 - val_acc: 0.6875
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0530 - acc: 0.9903 - val_loss: 0.4020 - val_acc: 0.7500
# Epoch 20/20
# 928/928 [==============================] - 6s 7ms/step - loss: 0.0339 - acc: 0.9946 - val_loss: 0.7208 - val_acc: 0.7500
#
# Test Accuracy is 0.75
#
# model_56 is saved
# Cross validation 57
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 11s 11ms/step - loss: 2.4862 - acc: 0.4968 - val_loss: 0.8894 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.7524 - acc: 0.5517 - val_loss: 0.7143 - val_acc: 0.5000
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.6144 - acc: 0.6983 - val_loss: 0.5752 - val_acc: 0.6250
# Epoch 4/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5521 - acc: 0.7338 - val_loss: 0.4969 - val_acc: 0.8125
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4536 - acc: 0.8136 - val_loss: 0.4415 - val_acc: 0.8125
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3709 - acc: 0.8621 - val_loss: 0.4325 - val_acc: 0.7500
# Epoch 7/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.3152 - acc: 0.8836 - val_loss: 0.4042 - val_acc: 0.7500
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2811 - acc: 0.8933 - val_loss: 0.3229 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2235 - acc: 0.9267 - val_loss: 0.3548 - val_acc: 0.8125
# Epoch 10/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1995 - acc: 0.9289 - val_loss: 0.3405 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1639 - acc: 0.9483 - val_loss: 0.3792 - val_acc: 0.7500
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1359 - acc: 0.9569 - val_loss: 0.4594 - val_acc: 0.7500
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1289 - acc: 0.9547 - val_loss: 0.3271 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1040 - acc: 0.9666 - val_loss: 0.2119 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1027 - acc: 0.9655 - val_loss: 0.3030 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0793 - acc: 0.9795 - val_loss: 0.3958 - val_acc: 0.8125
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0585 - acc: 0.9871 - val_loss: 0.3598 - val_acc: 0.8750
# Epoch 18/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0433 - acc: 0.9892 - val_loss: 0.3672 - val_acc: 0.8750
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0320 - acc: 0.9957 - val_loss: 0.2866 - val_acc: 0.8750
# Epoch 20/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0248 - acc: 0.9989 - val_loss: 0.2551 - val_acc: 0.8750
#
# Test Accuracy is 0.875
#
# model_57 is saved
# Cross validation 58
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 11s 12ms/step - loss: 2.2790 - acc: 0.5086 - val_loss: 0.5728 - val_acc: 0.7500
# Epoch 2/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.7196 - acc: 0.5991 - val_loss: 0.7173 - val_acc: 0.6250
# Epoch 3/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5758 - acc: 0.7101 - val_loss: 0.6975 - val_acc: 0.6875
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5189 - acc: 0.7996 - val_loss: 0.7438 - val_acc: 0.5000
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.4255 - acc: 0.8211 - val_loss: 0.7723 - val_acc: 0.6250
# Epoch 6/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3618 - acc: 0.8696 - val_loss: 0.6452 - val_acc: 0.6875
# Epoch 7/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3036 - acc: 0.8976 - val_loss: 0.6606 - val_acc: 0.6250
# Epoch 8/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2728 - acc: 0.9052 - val_loss: 0.6673 - val_acc: 0.6250
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2355 - acc: 0.9106 - val_loss: 0.7097 - val_acc: 0.6875
# Epoch 10/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2059 - acc: 0.9192 - val_loss: 0.9958 - val_acc: 0.6250
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1848 - acc: 0.9343 - val_loss: 0.7381 - val_acc: 0.6250
# Epoch 12/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.1529 - acc: 0.9494 - val_loss: 0.7846 - val_acc: 0.6875
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1290 - acc: 0.9644 - val_loss: 0.8071 - val_acc: 0.8125
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1084 - acc: 0.9677 - val_loss: 0.8990 - val_acc: 0.7500
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0860 - acc: 0.9774 - val_loss: 0.8316 - val_acc: 0.6875
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0625 - acc: 0.9903 - val_loss: 0.8833 - val_acc: 0.8125
# Epoch 17/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0517 - acc: 0.9881 - val_loss: 0.9418 - val_acc: 0.8125
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0384 - acc: 0.9946 - val_loss: 1.0691 - val_acc: 0.8125
# Epoch 19/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0381 - acc: 0.9946 - val_loss: 0.8994 - val_acc: 0.7500
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0250 - acc: 0.9989 - val_loss: 0.8219 - val_acc: 0.8125
#
# Test Accuracy is 0.8125
#
# model_58 is saved
# Cross validation 59
# Train on 928 samples, validate on 16 samples
# Epoch 1/20
# 928/928 [==============================] - 11s 12ms/step - loss: 3.3928 - acc: 0.5032 - val_loss: 0.9518 - val_acc: 0.5000
# Epoch 2/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.8532 - acc: 0.5463 - val_loss: 0.6523 - val_acc: 0.6250
# Epoch 3/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.6812 - acc: 0.5959 - val_loss: 0.6057 - val_acc: 0.6875
# Epoch 4/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.5812 - acc: 0.7457 - val_loss: 0.5139 - val_acc: 0.8750
# Epoch 5/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.5097 - acc: 0.7963 - val_loss: 0.4036 - val_acc: 0.9375
# Epoch 6/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.4339 - acc: 0.8190 - val_loss: 0.3934 - val_acc: 0.8750
# Epoch 7/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.3568 - acc: 0.8481 - val_loss: 0.3602 - val_acc: 0.8125
# Epoch 8/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2917 - acc: 0.8836 - val_loss: 0.2802 - val_acc: 0.8750
# Epoch 9/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2504 - acc: 0.9073 - val_loss: 0.3958 - val_acc: 0.8750
# Epoch 10/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.2169 - acc: 0.9300 - val_loss: 0.2476 - val_acc: 0.8750
# Epoch 11/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.2202 - acc: 0.9246 - val_loss: 0.3241 - val_acc: 0.8750
# Epoch 12/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1695 - acc: 0.9450 - val_loss: 0.3294 - val_acc: 0.8750
# Epoch 13/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1325 - acc: 0.9526 - val_loss: 0.1922 - val_acc: 0.8750
# Epoch 14/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.1039 - acc: 0.9688 - val_loss: 0.5647 - val_acc: 0.8750
# Epoch 15/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0804 - acc: 0.9784 - val_loss: 0.6441 - val_acc: 0.8750
# Epoch 16/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0561 - acc: 0.9903 - val_loss: 0.6213 - val_acc: 0.8750
# Epoch 17/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0409 - acc: 0.9935 - val_loss: 0.6100 - val_acc: 0.8750
# Epoch 18/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0349 - acc: 0.9935 - val_loss: 0.9333 - val_acc: 0.8750
# Epoch 19/20
# 928/928 [==============================] - 5s 6ms/step - loss: 0.0233 - acc: 1.0000 - val_loss: 1.0335 - val_acc: 0.8750
# Epoch 20/20
# 928/928 [==============================] - 6s 6ms/step - loss: 0.0182 - acc: 0.9989 - val_loss: 0.9577 - val_acc: 0.8750
#
# Test Accuracy is 0.875
#
# model_59 is saved

# %% [markdown]
# # Part 6. Total Accuracy
#
# At each cross-validation fold, the predictive accuracy is calculated.
#
# You can also get mean accuracy value of all cross-validation folds.
#
# And after cross-validation, you can load the results from the data frame file, so you don't have to train again.

# %%
#Loading the data frame.
df = pd.read_csv(os.path.join(result_path, dataframe_filename))
df.head()
# Out:
#    Unnamed: 0  index                                          data_path  type  \
# 0           0      0  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 1           1      1  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 2           2      2  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 3           3      3  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 4           4      4  ../data/derivatives/trial_images/sub_01/heat_t...  heat
#
#    type_onehot subject  predicted_type_onehot model_name  \
# 0            1  sub_01                      1   model_01
# 1            1  sub_01                      1   model_01
# 2            1  sub_01                      1   model_01
# 3            1  sub_01                      0   model_01
# 4            1  sub_01                      1   model_01
#
#                                 model_weight_path  model_acc  model_loss
# 0  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 1  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 2  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 3  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 4  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275

# %%
#Extract models names
model_names = df['model_name'].unique()
total_acc = []

#Extract Accuracy at each models
for model_name in model_names:
    total_acc.append(df[df['model_name'] == model_name]['model_acc'].unique()[0])
    
total_acc = np.array(total_acc)

# %%
plt.hist(total_acc, bins=20)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3.,  0.,  0.,  8.,  0.,  0., 12.,  0.,
#          0., 13.,  0.,  0., 10.,  0., 12.]),
#  array([0.5625  , 0.584375, 0.60625 , 0.628125, 0.65    , 0.671875,
#         0.69375 , 0.715625, 0.7375  , 0.759375, 0.78125 , 0.803125,
#         0.825   , 0.846875, 0.86875 , 0.890625, 0.9125  , 0.934375,
#         0.95625 , 0.978125, 1.      ]),
#  <a list of 20 Patch objects>)

# %%
print("Total Accuracy mean {}".format(total_acc.mean()))
print("Total Accuracy std {}".format(total_acc.std()))
# Out:
# Total Accuracy mean 0.8665254237288136
# Total Accuracy std 0.10061886569274686

# %% [markdown]
# # Part 7. Layer-wise Relevance Propagation

# %%
#Loading the data frame, if you need.
df = pd.read_csv(os.path.join(result_path, dataframe_filename))
df.head()
# Out:
#    Unnamed: 0  index                                          data_path  type  \
# 0           0      0  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 1           1      1  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 2           2      2  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 3           3      3  ../data/derivatives/trial_images/sub_01/heat_t...  heat
# 4           4      4  ../data/derivatives/trial_images/sub_01/heat_t...  heat
#
#    type_onehot subject  predicted_type_onehot model_name  \
# 0            1  sub_01                      1   model_01
# 1            1  sub_01                      1   model_01
# 2            1  sub_01                      1   model_01
# 3            1  sub_01                      0   model_01
# 4            1  sub_01                      1   model_01
#
#                                 model_weight_path  model_acc  model_loss
# 0  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 1  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 2  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 3  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275
# 4  ../results/cnn_lrp/model_01/model_01_weight.h5      0.875    0.117275

# %% [markdown]
# LRP need the input data to calculate Relevance scores.

# %%
logo = LeaveOneGroupOut()

#sub_01 will be test set 
train_index, test_index = logo.split(X=df['data_path'], y=df['type_onehot'], groups=df['subject']=='sub_01')

train_index = train_index[1]
test_index = test_index[1]

#Load numpy array data from data path
train_X, train_y, test_X, test_y, fmri_shape = load_dat(df, train_index, test_index, transpose_index=[3,2,1,0])
print("train_X shape is {}".format(train_X.shape))
print("test_X shape is {}".format(test_X.shape))
# Out:
# train_X shape is (928, 68, 95, 79)
# test_X shape is (16, 68, 95, 79)

# %% [markdown]
# Since we already checked cross-validation results, for LRP, we are going to train a model using all data.

# %%
train_all_index = np.concatenate((test_index, train_index))
train_all_X = np.concatenate((test_X, train_X), axis=0)
train_all_y = np.concatenate((test_y,train_y))

# %%
# Create & train model
model_for_lrp, score = train_model(fmri_shape, train_all_X, train_all_y, test_X, test_y, mini_batch_size=128, epochs=20, patience=20)
# Out:
# Train on 944 samples, validate on 16 samples
# Epoch 1/20
# 944/944 [==============================] - 11s 11ms/step - loss: 2.0742 - acc: 0.5095 - val_loss: 1.3972 - val_acc: 0.5000
# Epoch 2/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.7898 - acc: 0.5646 - val_loss: 0.5964 - val_acc: 0.6875
# Epoch 3/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.5845 - acc: 0.7320 - val_loss: 0.4929 - val_acc: 0.7500
# Epoch 4/20
# 944/944 [==============================] - 5s 6ms/step - loss: 0.4558 - acc: 0.8411 - val_loss: 0.3217 - val_acc: 1.0000
# Epoch 5/20
# 944/944 [==============================] - 5s 6ms/step - loss: 0.3505 - acc: 0.8824 - val_loss: 0.1675 - val_acc: 1.0000
# Epoch 6/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.2870 - acc: 0.8909 - val_loss: 0.1573 - val_acc: 1.0000
# Epoch 7/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.2141 - acc: 0.9248 - val_loss: 0.1118 - val_acc: 1.0000
# Epoch 8/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.1743 - acc: 0.9354 - val_loss: 0.0988 - val_acc: 1.0000
# Epoch 9/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.1359 - acc: 0.9608 - val_loss: 0.0956 - val_acc: 1.0000
# Epoch 10/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.1162 - acc: 0.9682 - val_loss: 0.0847 - val_acc: 1.0000
# Epoch 11/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.1417 - acc: 0.9322 - val_loss: 0.0793 - val_acc: 1.0000
# Epoch 12/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0969 - acc: 0.9682 - val_loss: 0.0710 - val_acc: 1.0000
# Epoch 13/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0667 - acc: 0.9852 - val_loss: 0.0425 - val_acc: 1.0000
# Epoch 14/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0499 - acc: 0.9894 - val_loss: 0.0343 - val_acc: 1.0000
# Epoch 15/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0348 - acc: 0.9968 - val_loss: 0.0247 - val_acc: 1.0000
# Epoch 16/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0263 - acc: 0.9989 - val_loss: 0.0170 - val_acc: 1.0000
# Epoch 17/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0205 - acc: 0.9989 - val_loss: 0.0201 - val_acc: 1.0000
# Epoch 18/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0164 - acc: 1.0000 - val_loss: 0.0073 - val_acc: 1.0000
# Epoch 19/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 20/20
# 944/944 [==============================] - 6s 6ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
#
# Test Accuracy is 1.0

# %% [markdown]
# For LRP, you can select ouput node for calculating relevance score. `'None'` means **max_activation** node and you can use specific node number like `0` or `1`

# %%
import innvestigate
import innvestigate.utils as iutils
import innvestigate.utils.visualizations as ivis
import nibabel as nib

selection_index_LRP=[0,1,None]

# %% [markdown]
# For this example, We are going to use subject-wise averaged images as input images(**each subject will have one averaged heat trial image and one averaged rejection trial image**) for LRP
#
# LRP start!

# %%
subject_list = df['subject'].unique()
type_list = df['type'].unique()
model_wo_softmax = iutils.keras.graph.model_wo_softmax(model_for_lrp)

for selection_index in selection_index_LRP:
    # Configure analysis methods and properties
    if selection_index == None:
        method = ("lrp.epsilon",    {"epsilon": 1,"neuron_selection_mode":"max_activation"},    ivis.heatmap,    "LRP-Epsilon")
    else:    
        method = ("lrp.epsilon",    {"epsilon": 1, "neuron_selection_mode" : "index"},    ivis.heatmap,     "LRP-Epsilon")
        
    
    # Create analyzer.
    analyzer = innvestigate.create_analyzer(method[0],        # analysis method identifier
                                            model_wo_softmax, # model without softmax output
                                            **method[1])      # optional analysis parameters
    
    lrp_index = 'lrp_index_'+str(selection_index)
    lrp_result_path = os.path.join(result_path, 'LRP', lrp_index)
    
    #Making folders
    if not os.path.exists(lrp_result_path):
        os.makedirs(lrp_result_path)
        
        
    #Analyzing LRP, averaging images
    for subject in subject_list:
        for stimulus_type in type_list:
            indexed_path = df['data_path'].loc[(df['subject']==subject) & (df['type']==stimulus_type)].to_numpy()
            temp_nib_images = image.load_img(indexed_path)
            temp_avg_nib_images = image.mean_img(temp_nib_images)
            x = temp_avg_nib_images.get_fdata()
            x = x.transpose(2,1,0)

            # Add batch axis.
            x = x[None, :, :, :]

            # Analyze
            if selection_index == None:
                a = analyzer.analyze(x)
            else:
                a = analyzer.analyze(x, neuron_selection=selection_index)

            # Remove batch axis    
            a = a.squeeze() 

            trans_a = a.transpose(2,1,0)
            nib_a = nib.Nifti1Image(trans_a, temp_avg_nib_images.affine)

            lrp_file_name = 'LRP_' + subject + '_' + stimulus_type
            lrp_file_path = os.path.join(lrp_result_path, lrp_file_name)

            #Saving LRP results image
            nib.save(nib_a, lrp_file_path)

            print('{} is saved'.format(lrp_file_path))

# %% [markdown]
# # Part 8. Visualization
#
# Now we have relevance scores of input data, which are same number as input images(each subject has two images, one for averaged heat trial and one for averaged rejection trial, from 59 subject, so total images will be 59x2 = 118).

# %%
datasource = nio.DataGrabber()
datasource.inputs.base_directory = result_path
datasource.inputs.template = 'LRP/*None/*heat*'
datasource.inputs.sort_filelist = True
lrp_heat_avg_list = datasource.run().outputs.get()['outfiles']

datasource.inputs.template = 'LRP/*None/*reject*'
lrp_rej_avg_list = datasource.run().outputs.get()['outfiles']

# %%
print("Number of averaged heat LRP images are {}\n".format(len(lrp_heat_avg_list)))
print("Number of averaged rejection LRP images are {}\n".format(len(lrp_rej_avg_list)))
print("Number of total averaged LRP images are {}\n".format(len(lrp_heat_avg_list) + len(lrp_rej_avg_list)))

print(np.array(lrp_heat_avg_list)[:10])
print(np.array(lrp_rej_avg_list)[:10])
# Out:
# Number of averaged heat LRP images are 59
#
# Number of averaged rejection LRP images are 59
#
# Number of total averaged LRP images are 118
#
# ['/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_01_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_02_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_03_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_04_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_05_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_06_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_07_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_08_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_09_heat.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_10_heat.nii']
# ['/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_01_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_02_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_03_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_04_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_05_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_06_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_07_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_08_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_09_reject.nii'
#  '/home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/results/cnn_lrp/LRP/lrp_index_None/LRP_sub_10_reject.nii']

# %% [markdown]
# You can visualize z-score of one-sample t-test for each trial type(heat, rejection).
#
# For one-sample t-test, we will use [Nistats](https://nistats.github.io/index.html)
#
# You can refer the detail of [Nistates's one-sample t-test](https://nistats.github.io/auto_examples/03_second_level_models/plot_thresholding.html#sphx-glr-auto-examples-03-second-level-models-plot-thresholding-py)

# %%
from nistats.second_level_model import SecondLevelModel

#Uncorrected one-sample t-test
dm_heat_avg_lrp = pd.DataFrame([1] * len(lrp_heat_avg_list), columns=['intercept'])
heat_avg_lrp_2level = SecondLevelModel(smoothing_fwhm=5).fit(lrp_heat_avg_list, design_matrix=dm_heat_avg_lrp)
heat_avg_lrp_zmap = heat_avg_lrp_2level.compute_contrast(output_type='z_score')

dm_rej_avg_lrp = pd.DataFrame([1] * len(lrp_rej_avg_list), columns=['intercept'])
rej_avg_lrp_2level = SecondLevelModel(smoothing_fwhm=5).fit(lrp_rej_avg_list, design_matrix=dm_rej_avg_lrp)
rej_avg_lrp_zmap = rej_avg_lrp_2level.compute_contrast(output_type='z_score')


from nistats.thresholding import map_threshold

#Corrected one-sample t-test(fpr, fdr, bonferroni)
heat_avg_lrp_fpr, heat_avg_fpr_thresh = map_threshold(heat_avg_lrp_zmap, alpha=.001, height_control='fpr', cluster_threshold=10)
heat_avg_lrp_fdr, heat_avg_fdr_thresh = map_threshold(heat_avg_lrp_zmap, alpha=.05, height_control='fdr')
heat_avg_lrp_bonfer, heat_avg_bonfer_thresh = map_threshold(heat_avg_lrp_zmap, alpha=.05, height_control='bonferroni')

rej_avg_lrp_fpr, rej_avg_fpr_thresh = map_threshold(rej_avg_lrp_zmap, alpha=.001, height_control='fpr', cluster_threshold=10)
rej_avg_lrp_fdr, rej_avg_fdr_thresh = map_threshold(rej_avg_lrp_zmap, alpha=.05, height_control='fdr')
rej_avg_lrp_bonfer, rej_avg_bonfer_thresh = map_threshold(rej_avg_lrp_zmap, alpha=.05, height_control='bonferroni')

# %% [markdown]
# For plotting one-sample t-test results, we are using `nilearn.plotting`
#
# Details in [Plotting brain images](http://nilearn.github.io/plotting/index.html)

# %%
from nilearn import plotting

#Setting coordinates for plotting
x_coords = [-52,-42,-30,-18,24,38,50]
y_coords = [4,8,10,20,22,28,34]
z_coords = [-22,-20,-12,-4,-2,6,14]

from scipy.stats import norm

#Getting z-value of 0.001 p-value
p_val = 0.001
p_val_to_z_val = norm.isf(p_val)

# %%
#Plotting uncorrected one-sample t-test
plotting.plot_stat_map(heat_avg_lrp_zmap, threshold=p_val_to_z_val, display_mode='x', cut_coords=x_coords, title='Heat avg LRP, Uncorrected, X')
plotting.plot_stat_map(heat_avg_lrp_zmap, threshold=p_val_to_z_val, display_mode='y', cut_coords=y_coords, title='Heat avg LRP, Uncorrected, Y')
plotting.plot_stat_map(heat_avg_lrp_zmap, threshold=p_val_to_z_val, display_mode='z', cut_coords=z_coords, title='Heat avg LRP, Uncorrected, Z')

plotting.plot_stat_map(rej_avg_lrp_zmap, threshold=p_val_to_z_val, display_mode='x', cut_coords=x_coords, title='Rejection avg LRP, Uncorrected, X')
plotting.plot_stat_map(rej_avg_lrp_zmap, threshold=p_val_to_z_val, display_mode='y', cut_coords=y_coords, title='Rejection avg LRP, Uncorrected, Y')
plotting.plot_stat_map(rej_avg_lrp_zmap, threshold=p_val_to_z_val, display_mode='z', cut_coords=z_coords, title='Rejection avg LRP, Uncorrected, Z')

# %%
#Plotting corrected one-sample t-test(fpr)
plotting.plot_stat_map(heat_avg_lrp_fpr, threshold=heat_avg_fpr_thresh, display_mode='x', cut_coords=x_coords, title='Heat avg LRP, fpr, X')
plotting.plot_stat_map(heat_avg_lrp_fpr, threshold=heat_avg_fpr_thresh, display_mode='y', cut_coords=y_coords, title='Heat avg LRP, fpr, Y')
plotting.plot_stat_map(heat_avg_lrp_fpr, threshold=heat_avg_fpr_thresh, display_mode='z', cut_coords=z_coords, title='Heat avg LRP, fpr, Z')

plotting.plot_stat_map(rej_avg_lrp_fpr, threshold=rej_avg_fpr_thresh, display_mode='x', cut_coords=x_coords, title='Rejection avg LRP, fpr, X')
plotting.plot_stat_map(rej_avg_lrp_fpr, threshold=rej_avg_fpr_thresh, display_mode='y', cut_coords=y_coords, title='Rejection avg LRP, fpr, Y')
plotting.plot_stat_map(rej_avg_lrp_fpr, threshold=rej_avg_fpr_thresh, display_mode='z', cut_coords=z_coords, title='Rejection avg LRP, fpr, Z')

# %%
#Plotting corrected one-sample t-test(fdr)
plotting.plot_stat_map(heat_avg_lrp_fdr, threshold=heat_avg_fdr_thresh, display_mode='x', cut_coords=x_coords, title='Heat avg LRP, fdr, X')
plotting.plot_stat_map(heat_avg_lrp_fdr, threshold=heat_avg_fdr_thresh, display_mode='y', cut_coords=y_coords, title='Heat avg LRP, fdr, Y')
plotting.plot_stat_map(heat_avg_lrp_fdr, threshold=heat_avg_fdr_thresh, display_mode='z', cut_coords=z_coords, title='Heat avg LRP, fdr, Z')

plotting.plot_stat_map(rej_avg_lrp_fdr, threshold=rej_avg_fdr_thresh, display_mode='x', cut_coords=x_coords, title='Rejection avg LRP, fdr, X')
plotting.plot_stat_map(rej_avg_lrp_fdr, threshold=rej_avg_fdr_thresh, display_mode='y', cut_coords=y_coords, title='Rejection avg LRP, fdr, Y')
plotting.plot_stat_map(rej_avg_lrp_fdr, threshold=rej_avg_fdr_thresh, display_mode='z', cut_coords=z_coords, title='Rejection avg LRP, fdr, Z')

# %%
#Plotting corrected one-sample t-test(bonferroni)
plotting.plot_stat_map(heat_avg_lrp_bonfer, threshold=heat_avg_bonfer_thresh, display_mode='x', cut_coords=x_coords, title='Heat avg LRP, bonferroni, X')
plotting.plot_stat_map(heat_avg_lrp_bonfer, threshold=heat_avg_bonfer_thresh, display_mode='y', cut_coords=y_coords, title='Heat avg LRP, bonferroni, Y')
plotting.plot_stat_map(heat_avg_lrp_bonfer, threshold=heat_avg_bonfer_thresh, display_mode='z', cut_coords=z_coords, title='Heat avg LRP, bonferroni, Z')

plotting.plot_stat_map(rej_avg_lrp_bonfer, threshold=rej_avg_bonfer_thresh, display_mode='x', cut_coords=x_coords, title='Rejection avg LRP, bonferroni, X')
plotting.plot_stat_map(rej_avg_lrp_bonfer, threshold=rej_avg_bonfer_thresh, display_mode='y', cut_coords=y_coords, title='Rejection avg LRP, bonferroni, Y')
plotting.plot_stat_map(rej_avg_lrp_bonfer, threshold=rej_avg_bonfer_thresh, display_mode='z', cut_coords=z_coords, title='Rejection avg LRP, bonferroni, Z')

# %%
from nilearn import datasets, surface

#plotting surface stat map of uncorrected one-sample t-test
fsaverage = datasets.fetch_surf_fsaverage()

# %%
heat_right = surface.vol_to_surf(heat_avg_lrp_zmap, fsaverage.pial_right)
heat_left = surface.vol_to_surf(heat_avg_lrp_zmap, fsaverage.pial_left)

plotting.plot_surf_stat_map(fsaverage.infl_right, heat_right, hemi='right',
                            title='Surface right hemisphere of heat', colorbar=True,
                            threshold=p_val_to_z_val, bg_map=fsaverage.sulc_right)

plotting.plot_surf_stat_map(fsaverage.infl_left, heat_left, hemi='left',
                            title='Surface left hemisphere of heat', colorbar=True,
                            threshold=p_val_to_z_val, bg_map=fsaverage.sulc_left)
plotting.show()

# %%
rej_right = surface.vol_to_surf(rej_avg_lrp_zmap, fsaverage.pial_right)
rej_left = surface.vol_to_surf(rej_avg_lrp_zmap, fsaverage.pial_left)

plotting.plot_surf_stat_map(fsaverage.infl_right, rej_right, hemi='right',
                            title='Surface right hemisphere of heat', colorbar=True,
                            threshold=p_val_to_z_val, bg_map=fsaverage.sulc_right)

plotting.plot_surf_stat_map(fsaverage.infl_left, rej_left, hemi='left',
                            title='Surface left hemisphere of heat', colorbar=True,
                            threshold=p_val_to_z_val, bg_map=fsaverage.sulc_left)
plotting.show()

# %% [markdown]
# If you get `NotImplementedError: It is not currently possible to manually set the aspect on 3D axes` error when you execute above cells, this is matplotlib version problem.
#
# In order to solve this problem, please reinstall matplotlib 3.0.2 version and restart your jupyter notebook kernel.

# %%
# If you want to reinstall matplotlib, execute the following codes.

# !pip uninstall -y matplotlib
# !pip install matplotlib==3.0.2

# %% [markdown]
# If you restart kernel, all variables are dissapear.
# But you don't have to run all the cells again for visualization.
#
# Just run those two cells
#
# ```
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from nilearn import image
# import nipype.interfaces.io as nio
# import os
#
# import tensorflow as tf
# from sklearn.model_selection import LeaveOneGroupOut
# from keras.models import load_model
#
# %matplotlib inline
# ```
# ---
# ```
# datapath = '../data/derivatives/trial_images'
# result_path = '../results/test2_avg_trial_lrp'
# dataframe_filename = 'cnn_lrp_dataframe.csv'
#
# ```
#
# and cells for **part8 visualization**.
