# %% [markdown]
# # Part 0. Description
#
# This script is a part of our work on the intepretation of machine learning models in neuroimaging. See more [details](https://github.com/cocoanlab/interpret_ml_neuroimaging)
#
# In this example, we will classify **Heat pain trial** and **Rejection trial** fMRI data using Convolutional Neural Network (CNN) and we will use Layer-wise Relevance Propagation (LRP) [(Bach et al., 2015)](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0130140) to explain the predictions of the model.
#
# The data consists of 59 subjects. Each subject has 8 heat trials and 8 rejection trials.
#
# We will do Leave-One-Subject-Out cross-validation which means 59-fold cross-validation will be executed. In order to track which subject is held-out as a test set, we save the model number matched with the subject number. For example, if `sub_01` is the test set (first fold cross-validation), then model name is `model_01`
#
# Since we have 59 folds's results and models, it will be difficult to manage all of them. So we will use data matrix so that we can easily handle the results and models.
#
# When initialized, the data matrix contains: `'data_path'`(**where the data is saved**), `'type'`(**which type of stimulus is used on this data**), `'type_onehot'`(**One-Hot encoding of type**), `'subject'`(**subject number**)
#
# After the CNN model training, the following columns will be added:
#
# `'predicted_type_onehot'`(**predicted type by trained CNN model**), `'model'`(**which model is used for prediction**), `'model_path'`(**where the model is saved**), `'model_acc'`(**accuracy of model for test data sets**), `'model_loss'`(**loss of model for test data sets**), `'lrp_index_{node_number}_path'`(**result of LRP by output node index**)

# %%
#The following is an example of the output data matrix of this script. Do not execute this cell before you train CNN models.
df.head(n=20)
# Out:
#                                             data_path    type type_onehot  \
# 0   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 1   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 2   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 3   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 4   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 5   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 6   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 7   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 8   /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 9   /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 10  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 11  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 12  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 13  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 14  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 15  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 16  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 17  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 18  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 19  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
#
#    subject predicted_type_onehot     model  \
# 0   sub_01                     1  model_01
# 1   sub_01                     1  model_01
# 2   sub_01                     1  model_01
# 3   sub_01                     1  model_01
# 4   sub_01                     1  model_01
# 5   sub_01                     1  model_01
# 6   sub_01                     0  model_01
# 7   sub_01                     1  model_01
# 8   sub_01                     0  model_01
# 9   sub_01                     0  model_01
# 10  sub_01                     0  model_01
# 11  sub_01                     0  model_01
# 12  sub_01                     0  model_01
# 13  sub_01                     0  model_01
# 14  sub_01                     0  model_01
# 15  sub_01                     0  model_01
# 16  sub_02                     1  model_02
# 17  sub_02                     0  model_02
# 18  sub_02                     1  model_02
# 19  sub_02                     1  model_02
#
#                                            model_path model_acc model_loss  \
# 0   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 1   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 2   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 3   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 4   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 5   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 6   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 7   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 8   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 9   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 10  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 11  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 12  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 13  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 14  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 15  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.9375   0.241855
# 16  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.6875   0.586685
# 17  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.6875   0.586685
# 18  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.6875   0.586685
# 19  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    0.6875   0.586685
#
#                                      lrp_index_0_path  \
# 0   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 1   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 2   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 3   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 4   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 5   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 6   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 7   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 8   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 9   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 10  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 11  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 12  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 13  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 14  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 15  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 16  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 17  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 18  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 19  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
#
#                                      lrp_index_1_path  \
# 0   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 1   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 2   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 3   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 4   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 5   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 6   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 7   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 8   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 9   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 10  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 11  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 12  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 13  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 14  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 15  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 16  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 17  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 18  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 19  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
#
#                                   lrp_index_None_path
# 0   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 1   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 2   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 3   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 4   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 5   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 6   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 7   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 8   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 9   /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 10  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 11  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 12  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 13  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 14  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 15  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 16  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 17  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 18  /home/cocoan-gpu1/Documents/interpret_ml_neuro...
# 19  /home/cocoan-gpu1/Documents/interpret_ml_neuro...

# %% [markdown]
# # Part 1. Initializing Data Matrix

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nilearn import image, plotting
import nipype.interfaces.io as nio
import os

# %matplotlib inline
# Out:
# /home/cocoan-gpu1/anaconda3/envs/nature_protocol/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# Setting base directory(`datapath`) for searching files and saving results(`result_path`, `dataframe_filename`)

# %%
datapath = '../data/derivatives/trial_images'
result_path = './results_epoch50/'
dataframe_filename = 'cnn_lrp_dataframe.csv'

# %% [markdown]
# This is a template of files that you want to find in the base directory(`datapath`).

# %%
search_template = 'sub_*/*.nii'

# %% [markdown]
# We will use `nipype.interfaces.io.DataGrabber()` to get the list of the files in the  directory.
#
# If you want to know the details of `DataGrabber()`, see this [reference](https://miykael.github.io/nipype_tutorial/notebooks/basic_data_input.html)

# %%
datasource = nio.DataGrabber()
datasource.inputs.base_directory = datapath
datasource.inputs.template = search_template
datasource.inputs.sort_filelist = True
all_imgs = datasource.run().outputs.get()['outfiles']

# %% [markdown]
# Initializing data matrix(`df`) with columns `data_path`, `type`, `type_onehot`, `subject`.

# %%
df = pd.DataFrame(all_imgs, columns=['data_path'])
df['type']= None
df['type_onehot'] = None
df['subject']= None

# %% [markdown]
# This is basic usage of `Pandas`. If you are not familiar with `Pandas`, see
#
# [Getting started](https://pandas.pydata.org/pandas-docs/stable/getting_started/index.html)
#
# [pandas.Series.str.find](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.find.html)
#
# [pandas.Series.str.extract](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.extract.html)

# %%
df.loc[df[df['data_path'].str.find('heat')!=-1].index, 'type'] = 'heat'
df.loc[df[df['data_path'].str.find('reject')!=-1].index, 'type'] = 'reject'
df.loc[df[df['data_path'].str.find('heat')!=-1].index, 'type_onehot'] = 1
df.loc[df[df['data_path'].str.find('reject')!=-1].index, 'type_onehot'] = 0
df['subject'] = df['data_path'].str.extract(r'(sub_\d\d)')

# %% [markdown]
# You can see the first **n** rows of data matrix using `df.head(n=n)`
#
# Since we have not trained the CNN model nor performed LRP, the data matrix contains only details about our input data.  As we go further through the script, more columns will be added.

# %%
df.head(n=20)
# Out:
#                                             data_path    type type_onehot  \
# 0   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 1   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 2   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 3   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 4   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 5   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 6   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 7   /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 8   /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 9   /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 10  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 11  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 12  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 13  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 14  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 15  /home/cocoan-gpu1/Documents/interpret_ml_neuro...  reject           0
# 16  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 17  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 18  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
# 19  /home/cocoan-gpu1/Documents/interpret_ml_neuro...    heat           1
#
#    subject
# 0   sub_01
# 1   sub_01
# 2   sub_01
# 3   sub_01
# 4   sub_01
# 5   sub_01
# 6   sub_01
# 7   sub_01
# 8   sub_01
# 9   sub_01
# 10  sub_01
# 11  sub_01
# 12  sub_01
# 13  sub_01
# 14  sub_01
# 15  sub_01
# 16  sub_02
# 17  sub_02
# 18  sub_02
# 19  sub_02

# %% [markdown]
# # Part 2. Loading Data Function
#
# The following code defines a function that we will use later to load data.

# %%
def load_dat(tr_path_X, te_path_X):
    
    from nilearn import image
    #Count data number
    tr_dat_num = tr_path_X.shape[0]
    te_dat_num = te_path_X.shape[0]
    
    #Loading temporal image for shape
    temp_img = image.load_img(tr_path_X[0])
    img_x, img_y, img_z = temp_img.shape

    #Preallocation
    tr_X = np.ones((tr_dat_num, img_x, img_y, img_z))
    te_X = np.ones((te_dat_num, img_x, img_y, img_z))
    
    for i in range(tr_dat_num):
        tr_X[i] = image.load_img(tr_path_X[i]).get_fdata()
    
    for i in range(te_dat_num):
        te_X[i] = image.load_img(te_path_X[i]).get_fdata()
    
    #Transpose matrix in order to match CNN model's input layer
    train_X = np.array(tr_X).transpose(0,3,2,1)
    test_X = np.array(te_X).transpose(0,3,2,1)
    
    return train_X, test_X

# %% [markdown]
# # Part 3. CNN Model

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## 3-1. Making a CNN model using `Keras`
#
# We are using `Keras` for making a CNN model. You can see details of `Keras` usage in [here](https://keras.io/)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# make CNN model with 6 layers, Flatten() is inserted between CNN and fully connected layers.

# %%
def make_custom_model_cnn_2D():
    
    model = Sequential() 
    model.add(Conv2D(8, (3,3), kernel_initializer='he_normal', padding='same', input_shape=(68,95,79)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))


    model.add(Conv2D(16, (3,3), kernel_initializer='he_normal', padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(32, (3,3), kernel_initializer='he_normal', padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3), kernel_initializer='he_normal', padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))


    model.add(Flatten()) 
    model.add(Dense(128, kernel_initializer='he_normal'))
    model.add(Activation('relu'))
    
    model.add(Dense(2, kernel_initializer='he_normal'))
    model.add(Activation('linear'))
    
    model.add(Activation('softmax'))
    
    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

    return model

# %% [markdown]
# ## 3-2. Function for model training

# %%
def train_model(train_X, train_y, test_X, test_y, mini_batch_size=128, epochs=20):

    # Optional: if you do not have enough GPUs, use the following line  
#     with tf.device('/cpu:0'):
    
    tr_data = {}
    tr_data['X_data'] = train_X
    tr_data['y_data'] = train_y

    te_data = {}
    te_data['X_data'] = test_X
    te_data['y_data'] = test_y

    tr_data['y_data'] = keras.utils.to_categorical(tr_data['y_data'], 2)
    te_data['y_data'] = keras.utils.to_categorical(te_data['y_data'], 2)

    training_sample_count = tr_data['X_data'].shape[0]


    # Initialize and compile the model
    model = make_custom_model_cnn_2D()
    model.compile(loss="categorical_crossentropy",
                  optimizer=Adam(),
                  metrics=["accuracy"])
    history = model.fit(tr_data['X_data'],
                        tr_data['y_data'],
                        batch_size=mini_batch_size,
                        epochs=epochs,
                        verbose=1)
    score = model.evaluate(te_data['X_data'], 
                           te_data['y_data'], 
                           verbose=0)
    
    print("\nAccuracy is {}\n".format(score[1]))
    
    return model,score

# %% [markdown]
# # Part 4. Model Training example

# %% [markdown]
# This is a 'test' training example for checking whether those codes are working.
#
# sub_01 will be the test dataset,
# the rest will be the training dataset

# %%
from sklearn.model_selection import LeaveOneGroupOut
logo = LeaveOneGroupOut()

# %%
#sub_01 will be test set 
train_index, test_index = logo.split(X=df['data_path'], y=df['type_onehot'], groups=df['subject']=='sub_01')

#Extract data path and labels from data matrix
tr_path_X, te_path_X = df['data_path'][train_index[1]].to_numpy(), df['data_path'][test_index[1]].to_numpy()
train_y, test_y = df['type_onehot'][train_index[1]].to_numpy(), df['type_onehot'][test_index[1]].to_numpy()

#Print their shapes
print("tr_path_X shape is {}".format(tr_path_X.shape))
print("te_path_X shape is {}".format(te_path_X.shape))
print("train_y shape is {}".format(train_y.shape))
print("test_y shape is {}".format(test_y.shape))

#Load numpy array data from data path
train_X, test_X = load_dat(tr_path_X, te_path_X)
print("train_X shape is {}".format(train_X.shape))
print("test_X shape is {}".format(test_X.shape))

# %% [markdown]
# Training

# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# Create & train model
model, score = train_model(train_X, train_y, test_X, test_y, mini_batch_size=128, epochs=20)

# %% [markdown]
# # Part 5. Leave-One-Subject-Out Cross-validation
#
# If the codes are working, we can perform 59-fold cross-validation.
#
# Keep in mind that **it will take hours**, depending on your computer performance.

# %%
from sklearn.model_selection import LeaveOneGroupOut
logo = LeaveOneGroupOut()

#Making new colums to save results
df['predicted_type_onehot'] = None
df['model'] = None
df['model_path'] = None
df['model_acc'] = None
df['model_loss'] = None

# %%
#Warning! It will take hours
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

#This time, it will be executed for all cross-validation sets
for i, (train_index, test_index) in enumerate(logo.split(X=df['data_path'], y=df['type_onehot'], groups=df['subject'])):
    
    #Extract data path and labels from data matrix
    tr_path_X, te_path_X = df['data_path'][train_index].to_numpy(), df['data_path'][test_index].to_numpy()
    train_y, test_y = df['type_onehot'][train_index].to_numpy(), df['type_onehot'][test_index].to_numpy()
    
    #Load numpy array data from data path
    train_X, test_X = load_dat(tr_path_X, te_path_X)
    print("Cross validation {}".format(i+1))
    
    #Create & train model
    model, score = train_model(train_X, train_y, test_X, test_y, mini_batch_size=128, epochs=50)
    
    #Saving Model
    model_name = 'model_{:02d}'.format(i+1)
    model_path = os.path.join(result_path, model_name)
    
    if not os.path.exists(model_path):
        os.makedirs(model_path)
        
    model_file = os.path.join(model_path, (model_name + '.npy'))
    np.save(model_file, np.array(model))
    print("{} is saved".format(model_name))
    
    #Saving results in data matrix
    df['model'][test_index] = model_name
    df['model_path'][test_index] = os.path.abspath(model_file)
    df['model_acc'][test_index] = score[1]
    df['model_loss'][test_index] = score[0]
    
    #Getting predictions for test data using trained CNN model
    test_images = list(zip(test_X, test_y))
    for p, (x, y) in enumerate(test_images):
        # Add batch axis.
        x = x[None, :, :, :]

        # Predict
        prob = model.predict_on_batch(x)[0]
        y_hat = prob.argmax()
        
        #Saving prediction results in data matrix
        df['predicted_type_onehot'][test_index[p]] = y_hat

    #Saving data matrix as csv file format
    df_csv_path = os.path.join(result_path, dataframe_filename)
    df.to_csv(df_csv_path)

# %% [markdown]
# # Part 6. Total Accuracy
#
# At each cross-validation fold, the predictive accuracy is calculated.
#
# You can also get mean accuracy value of all cross-validation folds.

# %%
#Extract models names
model_names = df['model'].unique()
total_acc = []

#Extract Accuracy at each models
for model_name in model_names:
    total_acc.append(df[df['model'] == model_name]['model_acc'].unique()[0])
    
total_acc = np.array(total_acc)

# %%
plt.hist(total_acc, bins=20)
# Out:
# (array([ 1.,  0.,  2.,  0.,  0.,  1.,  0.,  2.,  0.,  0.,  7.,  0.,  4.,
#          0.,  0., 12.,  0., 20.,  0., 10.]),
#  array([0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 , 0.675, 0.7  ,
#         0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875, 0.9  , 0.925,
#         0.95 , 0.975, 1.   ]),
#  <a list of 20 Patch objects>)

# %%
print("Total Accuracy mean {}".format(total_acc.mean()))
print("Total Accuracy std {}".format(total_acc.std()))
# Out:
# Total Accuracy mean 0.8707627118644068
# Total Accuracy std 0.1183978983698972

# %% [markdown]
# # Part 7. Layer-wise Relevance Propagation

# %%
import innvestigate
import innvestigate.utils as iutils
import innvestigate.utils.visualizations as ivis

# %%
def LRP(model, df, train_index, test_index, selection_index_LRP, result_path='./results'):
    
    #Loading data
    tr_path_X, te_path_X = df['data_path'][train_index].to_numpy(), df['data_path'][test_index].to_numpy()
    train_y, test_y = df['type_onehot'][train_index].to_numpy(), df['type_onehot'][test_index].to_numpy()
    train_X, test_X = load_dat(tr_path_X, te_path_X)
    test_images = list(zip(test_X, test_y))

    # Create model without training softmax
    model_wo_softmax = iutils.keras.graph.model_wo_softmax(model)
    
    for selection_index in selection_index_LRP:
        # Configure analysis methods and properties
        if selection_index == None:
            method = ("lrp.epsilon",    {"epsilon": 1,"neuron_selection_mode":"max_activation"},    ivis.heatmap,    "LRP-Epsilon")
        else:    
            method = ("lrp.epsilon",    {"epsilon": 1, "neuron_selection_mode" : "index"},    ivis.heatmap,     "LRP-Epsilon")

        # Create analyzer.
        analyzer = innvestigate.create_analyzer(method[0],        # analysis method identifier
                                                model_wo_softmax, # model without softmax output
                                                **method[1])      # optional analysis parameters
        
        #Set names and path for saving
        model_name = df['model'][test_index].unique()[0]
        lrp_index = 'lrp_index_'+str(selection_index)
        lrp_result_path = os.path.join(result_path, model_name, lrp_index)
        lrp_index_colum = lrp_index + '_path'
        
        if not os.path.exists(lrp_result_path):
            os.makedirs(lrp_result_path)

        #Analyzing LRP
        for p, (x, y) in enumerate(test_images):
            # Add batch axis.
            x = x[None, :, :, :]
            
            # Analyze
            if selection_index == None:
                a = analyzer.analyze(x)
            else:
                a = analyzer.analyze(x, neuron_selection=selection_index)
                
            lrp_file_name = df.iloc[test_index[p]]['type'] + '{:02d}'.format(p+1) + '.npy'
            lrp_file_path = os.path.join(lrp_result_path, lrp_file_name)
            
            #Saving LRP results image
            np.save(lrp_file_path, a)
            df[lrp_index_colum][test_index[p]] = os.path.abspath(lrp_file_path)

        print('{} of {} is saved'.format(lrp_index, model_name))

    return df

# %% [markdown]
# For LRP, you can select ouput node. `'None'` means **max_activation** node and you can use specific node number like `0` or `1`

# %%
selection_index_LRP=[0,1,None]

for i in selection_index_LRP:
    colum_name = 'lrp_index_' + str(i)+'_path'
    df[colum_name] = None

# %%
df_csv_path = os.path.join(result_path, dataframe_filename)

for i, (train_index, test_index) in enumerate(logo.split(X=df['data_path'], y=df['type_onehot'], groups=df['subject'])):
    
    #Loading trained CNN model for LRP
    model_path = df['model_path'][test_index].unique()[0]
    load_model = np.load(model_path, allow_pickle=True).item()
    print("\n{} is loaded".format(model_path))
    
    #Loading test data
    tr_path_X, te_path_X = df['data_path'][train_index].to_numpy(), df['data_path'][test_index].to_numpy()
    train_y, test_y = df['type_onehot'][train_index].to_numpy(), df['type_onehot'][test_index].to_numpy()
    train_X, test_X = load_dat(tr_path_X, te_path_X)
    
    #LRP
    df = LRP(load_model, df, train_index, test_index, selection_index_LRP, result_path)
    
    #Saving result data matrix
    df.to_csv(df_csv_path)
# Out:
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_01/model_01.npy is loaded
# lrp_index_0 of model_01 is saved
# lrp_index_1 of model_01 is saved
# lrp_index_None of model_01 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_02/model_02.npy is loaded
# lrp_index_0 of model_02 is saved
# lrp_index_1 of model_02 is saved
# lrp_index_None of model_02 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_03/model_03.npy is loaded
# lrp_index_0 of model_03 is saved
# lrp_index_1 of model_03 is saved
# lrp_index_None of model_03 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_04/model_04.npy is loaded
# lrp_index_0 of model_04 is saved
# lrp_index_1 of model_04 is saved
# lrp_index_None of model_04 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_05/model_05.npy is loaded
# lrp_index_0 of model_05 is saved
# lrp_index_1 of model_05 is saved
# lrp_index_None of model_05 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_06/model_06.npy is loaded
# lrp_index_0 of model_06 is saved
# lrp_index_1 of model_06 is saved
# lrp_index_None of model_06 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_07/model_07.npy is loaded
# lrp_index_0 of model_07 is saved
# lrp_index_1 of model_07 is saved
# lrp_index_None of model_07 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_08/model_08.npy is loaded
# lrp_index_0 of model_08 is saved
# lrp_index_1 of model_08 is saved
# lrp_index_None of model_08 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_09/model_09.npy is loaded
# lrp_index_0 of model_09 is saved
# lrp_index_1 of model_09 is saved
# lrp_index_None of model_09 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_10/model_10.npy is loaded
# lrp_index_0 of model_10 is saved
# lrp_index_1 of model_10 is saved
# lrp_index_None of model_10 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_11/model_11.npy is loaded
# lrp_index_0 of model_11 is saved
# lrp_index_1 of model_11 is saved
# lrp_index_None of model_11 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_12/model_12.npy is loaded
# lrp_index_0 of model_12 is saved
# lrp_index_1 of model_12 is saved
# lrp_index_None of model_12 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_13/model_13.npy is loaded
# lrp_index_0 of model_13 is saved
# lrp_index_1 of model_13 is saved
# lrp_index_None of model_13 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_14/model_14.npy is loaded
# lrp_index_0 of model_14 is saved
# lrp_index_1 of model_14 is saved
# lrp_index_None of model_14 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_15/model_15.npy is loaded
# lrp_index_0 of model_15 is saved
# lrp_index_1 of model_15 is saved
# lrp_index_None of model_15 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_16/model_16.npy is loaded
# lrp_index_0 of model_16 is saved
# lrp_index_1 of model_16 is saved
# lrp_index_None of model_16 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_17/model_17.npy is loaded
# lrp_index_0 of model_17 is saved
# lrp_index_1 of model_17 is saved
# lrp_index_None of model_17 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_18/model_18.npy is loaded
# lrp_index_0 of model_18 is saved
# lrp_index_1 of model_18 is saved
# lrp_index_None of model_18 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_19/model_19.npy is loaded
# lrp_index_0 of model_19 is saved
# lrp_index_1 of model_19 is saved
# lrp_index_None of model_19 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_20/model_20.npy is loaded
# lrp_index_0 of model_20 is saved
# lrp_index_1 of model_20 is saved
# lrp_index_None of model_20 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_21/model_21.npy is loaded
# lrp_index_0 of model_21 is saved
# lrp_index_1 of model_21 is saved
# lrp_index_None of model_21 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_22/model_22.npy is loaded
# lrp_index_0 of model_22 is saved
# lrp_index_1 of model_22 is saved
# lrp_index_None of model_22 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_23/model_23.npy is loaded
# lrp_index_0 of model_23 is saved
# lrp_index_1 of model_23 is saved
# lrp_index_None of model_23 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_24/model_24.npy is loaded
# lrp_index_0 of model_24 is saved
# lrp_index_1 of model_24 is saved
# lrp_index_None of model_24 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_25/model_25.npy is loaded
# lrp_index_0 of model_25 is saved
# lrp_index_1 of model_25 is saved
# lrp_index_None of model_25 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_26/model_26.npy is loaded
# lrp_index_0 of model_26 is saved
# lrp_index_1 of model_26 is saved
# lrp_index_None of model_26 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_27/model_27.npy is loaded
# lrp_index_0 of model_27 is saved
# lrp_index_1 of model_27 is saved
# lrp_index_None of model_27 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_28/model_28.npy is loaded
# lrp_index_0 of model_28 is saved
# lrp_index_1 of model_28 is saved
# lrp_index_None of model_28 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_29/model_29.npy is loaded
# lrp_index_0 of model_29 is saved
# lrp_index_1 of model_29 is saved
# lrp_index_None of model_29 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_30/model_30.npy is loaded
# lrp_index_0 of model_30 is saved
# lrp_index_1 of model_30 is saved
# lrp_index_None of model_30 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_31/model_31.npy is loaded
# lrp_index_0 of model_31 is saved
# lrp_index_1 of model_31 is saved
# lrp_index_None of model_31 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_32/model_32.npy is loaded
# lrp_index_0 of model_32 is saved
# lrp_index_1 of model_32 is saved
# lrp_index_None of model_32 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_33/model_33.npy is loaded
# lrp_index_0 of model_33 is saved
# lrp_index_1 of model_33 is saved
# lrp_index_None of model_33 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_34/model_34.npy is loaded
# lrp_index_0 of model_34 is saved
# lrp_index_1 of model_34 is saved
# lrp_index_None of model_34 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_35/model_35.npy is loaded
# lrp_index_0 of model_35 is saved
# lrp_index_1 of model_35 is saved
# lrp_index_None of model_35 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_36/model_36.npy is loaded
# lrp_index_0 of model_36 is saved
# lrp_index_1 of model_36 is saved
# lrp_index_None of model_36 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_37/model_37.npy is loaded
# lrp_index_0 of model_37 is saved
# lrp_index_1 of model_37 is saved
# lrp_index_None of model_37 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_38/model_38.npy is loaded
# lrp_index_0 of model_38 is saved
# lrp_index_1 of model_38 is saved
# lrp_index_None of model_38 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_39/model_39.npy is loaded
# lrp_index_0 of model_39 is saved
# lrp_index_1 of model_39 is saved
# lrp_index_None of model_39 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_40/model_40.npy is loaded
# lrp_index_0 of model_40 is saved
# lrp_index_1 of model_40 is saved
# lrp_index_None of model_40 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_41/model_41.npy is loaded
# lrp_index_0 of model_41 is saved
# lrp_index_1 of model_41 is saved
# lrp_index_None of model_41 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_42/model_42.npy is loaded
# lrp_index_0 of model_42 is saved
# lrp_index_1 of model_42 is saved
# lrp_index_None of model_42 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_43/model_43.npy is loaded
# lrp_index_0 of model_43 is saved
# lrp_index_1 of model_43 is saved
# lrp_index_None of model_43 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_44/model_44.npy is loaded
# lrp_index_0 of model_44 is saved
# lrp_index_1 of model_44 is saved
# lrp_index_None of model_44 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_45/model_45.npy is loaded
# lrp_index_0 of model_45 is saved
# lrp_index_1 of model_45 is saved
# lrp_index_None of model_45 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_46/model_46.npy is loaded
# lrp_index_0 of model_46 is saved
# lrp_index_1 of model_46 is saved
# lrp_index_None of model_46 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_47/model_47.npy is loaded
# lrp_index_0 of model_47 is saved
# lrp_index_1 of model_47 is saved
# lrp_index_None of model_47 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_48/model_48.npy is loaded
# lrp_index_0 of model_48 is saved
# lrp_index_1 of model_48 is saved
# lrp_index_None of model_48 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_49/model_49.npy is loaded
# lrp_index_0 of model_49 is saved
# lrp_index_1 of model_49 is saved
# lrp_index_None of model_49 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_50/model_50.npy is loaded
# lrp_index_0 of model_50 is saved
# lrp_index_1 of model_50 is saved
# lrp_index_None of model_50 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_51/model_51.npy is loaded
# lrp_index_0 of model_51 is saved
# lrp_index_1 of model_51 is saved
# lrp_index_None of model_51 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_52/model_52.npy is loaded
# lrp_index_0 of model_52 is saved
# lrp_index_1 of model_52 is saved
# lrp_index_None of model_52 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_53/model_53.npy is loaded
# lrp_index_0 of model_53 is saved
# lrp_index_1 of model_53 is saved
# lrp_index_None of model_53 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_54/model_54.npy is loaded
# lrp_index_0 of model_54 is saved
# lrp_index_1 of model_54 is saved
# lrp_index_None of model_54 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_55/model_55.npy is loaded
# lrp_index_0 of model_55 is saved
# lrp_index_1 of model_55 is saved
# lrp_index_None of model_55 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_56/model_56.npy is loaded
# lrp_index_0 of model_56 is saved
# lrp_index_1 of model_56 is saved
# lrp_index_None of model_56 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_57/model_57.npy is loaded
# lrp_index_0 of model_57 is saved
# lrp_index_1 of model_57 is saved
# lrp_index_None of model_57 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_58/model_58.npy is loaded
# lrp_index_0 of model_58 is saved
# lrp_index_1 of model_58 is saved
# lrp_index_None of model_58 is saved
#
# /home/cocoan-gpu1/Documents/interpret_ml_neuroimaging/scripts/results_epoch50/model_59/model_59.npy is loaded
# lrp_index_0 of model_59 is saved
# lrp_index_1 of model_59 is saved
# lrp_index_None of model_59 is saved

# %% [markdown]
# # Part 8. Visualization
#
# Now you have lots of images resulting from LRP, which are same in number as all input data.
#
# You can visualize mean of predicted type.

# %%
#Count number of predicted type
heat_count = df['predicted_type_onehot'][df['predicted_type_onehot']==1].count()
rejection_count = df['predicted_type_onehot'][df['predicted_type_onehot']==0].count()

# %% [markdown]
# You can chose what index result will visualize in this case we will visualize `'lrp_index_None_path'` or you can chose another index like `'lrp_index_0_path`, `'lrp_index_1_path'`

# %%
visualize_index = df['lrp_index_None_path']

# %%
#Preallocation
batch, img_x, img_y, img_z = np.load(visualize_index[0]).shape
heat_lrp = np.ones((heat_count, batch, img_x, img_y, img_z))
rejection_lrp = np.ones((rejection_count, batch, img_x, img_y, img_z))

# %%
#Loading LRP images
heat_count = 0
rejection_count = 0

for i in range(len(df)):
    if df['predicted_type_onehot'][i] == 1:
        heat_lrp[heat_count] = np.load(visualize_index[i])
        heat_count += 1
        
    elif df['predicted_type_onehot'][i] == 0:
        rejection_lrp[rejection_count] = np.load(visualize_index[i])
        rejection_count += 1
        
rejection_lrp = rejection_lrp.transpose(4,3,2,1,0)
heat_lrp = heat_lrp.transpose(4,3,2,1,0)

# %% [markdown]
# In order to make nibabel object, you need to have base Nifti file's affine matrix and header
#
# Details in [Nibabel images](https://nipy.org/nibabel/nibabel_images.html)

# %%
temp_nii = image.load_img(df.iloc[0]['data_path'])

import nibabel as nib
rejection_lrp_nib = nib.Nifti1Image(rejection_lrp, temp_nii.affine, temp_nii.header)
heat_lrp_nib = nib.Nifti1Image(heat_lrp, temp_nii.affine, temp_nii.header)

# %% [markdown]
# For plotting results, we are using `nilearn.plotting`
#
# Details in [Plotting brain images](http://nilearn.github.io/plotting/index.html)

# %%
#Checking image
plotting.plot_stat_map(rejection_lrp_nib.slicer[:,:,:,:,25])

# %%
#Averaging images through predicted type
heat_lrp_mean = heat_lrp.mean(axis=-1)
heat_lrp_mean_nib = nib.Nifti1Image(heat_lrp_mean, temp_nii.affine, temp_nii.header)

rejection_lrp_mean = rejection_lrp.mean(axis=-1)
rejection_lrp_mean_nib = nib.Nifti1Image(rejection_lrp_mean, temp_nii.affine, temp_nii.header)

# %%
plotting.view_img(rejection_lrp_mean_nib, threshold=0.00005, cut_coords=[36, -24, 22],title='rejection_lrp_mean')
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...

# %%
plotting.view_img(heat_lrp_mean_nib, threshold=0.00005, cut_coords=[36, -24, 22],title='heat_lrp_mean')
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagital) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;...

# %%
#Smoothing
reject_fwhm_4 = image.smooth_img(rejection_lrp_mean_nib, fwhm=4)
reject_fwhm_8 = image.smooth_img(rejection_lrp_mean_nib, fwhm=8)

heat_fwhm_4 = image.smooth_img(heat_lrp_mean_nib, fwhm=4)
heat_fwhm_8 = image.smooth_img(heat_lrp_mean_nib, fwhm=8)

# %%
#Plotting glass brain
plotting.plot_glass_brain(rejection_lrp_mean_nib, cut_coords=[36, -24, 22], title='rejection_lrp_mean_nib', colorbar=True, plot_abs=False)
plotting.plot_glass_brain(reject_fwhm_4, cut_coords=[36, -24, 22], title='reject_fwhm_4', colorbar=True, plot_abs=False)
plotting.plot_glass_brain(reject_fwhm_8, cut_coords=[36, -24, 22], title='reject_fwhm_8', colorbar=True, plot_abs=False)

# %%
plotting.plot_glass_brain(heat_lrp_mean_nib, cut_coords=[36, -24, 22], title='heat_lrp_mean_nib', colorbar=True, plot_abs=False)
plotting.plot_glass_brain(heat_fwhm_4, cut_coords=[36, -24, 22], title='heat_fwhm_4', colorbar=True, plot_abs=False)
plotting.plot_glass_brain(heat_fwhm_8, cut_coords=[36, -24, 22], title='heat_fwhm_8', colorbar=True, plot_abs=False)

# %%
#Plotting stat map
plotting.plot_stat_map(reject_fwhm_4, threshold=0.00005, display_mode='x', cut_coords=7, title='display_mode=x')
plotting.plot_stat_map(reject_fwhm_4, threshold=0.00005, display_mode='y', cut_coords=7, title='display_mode=y')
plotting.plot_stat_map(reject_fwhm_4, threshold=0.00005, display_mode='z', cut_coords=7, title='display_mode=z')

# %%
plotting.plot_stat_map(heat_fwhm_4, threshold=0.00005, display_mode='x', cut_coords=7, title='display_mode=x')
plotting.plot_stat_map(heat_fwhm_4, threshold=0.00005, display_mode='y', cut_coords=7, title='display_mode=y')
plotting.plot_stat_map(heat_fwhm_4, threshold=0.00005, display_mode='z', cut_coords=7, title='display_mode=z')

# %%
#plotting surface stat map
from nilearn import datasets, surface

fsaverage = datasets.fetch_surf_fsaverage()

reject_right = surface.vol_to_surf(reject_fwhm_4, fsaverage.pial_right)
reject_left = surface.vol_to_surf(reject_fwhm_4, fsaverage.pial_left)

# %%
plotting.plot_surf_stat_map(fsaverage.infl_right, reject_right, hemi='right',
                            title='Surface right hemisphere of reject', colorbar=True,
                            threshold=0.000005, bg_map=fsaverage.sulc_right)
plotting.plot_surf_stat_map(fsaverage.infl_left, reject_left, hemi='left',
                            title='Surface left hemisphere of reject', colorbar=True,
                            threshold=0.000005, bg_map=fsaverage.sulc_left)
plotting.show()

# %%
heat_right = surface.vol_to_surf(heat_fwhm_4, fsaverage.pial_right)
heat_left = surface.vol_to_surf(heat_fwhm_4, fsaverage.pial_left)

# %%
plotting.plot_surf_stat_map(fsaverage.infl_right, heat_right, hemi='right',
                            title='Surface right hemisphere of heat', colorbar=True,
                            threshold=0.000005, bg_map=fsaverage.sulc_right)
plotting.plot_surf_stat_map(fsaverage.infl_left, heat_left, hemi='left',
                            title='Surface left hemisphere of heat', colorbar=True,
                            threshold=0.000005, bg_map=fsaverage.sulc_left)
plotting.show()
